# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 09.09.2022
#
# Мягкий дедлайн: 23:59MSK 22.09.2022
#
# Жесткий дедлайн: 23:59MSK 29.09.2022

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: 5.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
print(type([1,2,3]))
# Out:
# <class 'list'>

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://i.gifer.com/TPaB.gif" style="width: 600px">
# <img src="https://i.gifer.com/IpYA.gif" style="width: 600px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/isupport/opt/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['matrix']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget 
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> крайне нежелательно.

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
# your code
data = pd.read_excel('end_seminar.xlsx')
data
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %% [markdown]
# <span style="color:green">
#     Пропуски есть в 6-ти колонках: 18_group (пропусков: 138), is_mi (343), is_first_time (2), 17_group (223), blended (223), is_ml_student (304)
#     </span>

# %%
# your code
data.isna().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых (постарайтесь избежать перечисления названий всех столбцов).

# %%
# your code
data.dtypes
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# 18_group                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# 17_group                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %% [markdown]
# <span style="color:green">
# только в двух столбцах тип <code>object</code> (в is_first_time и blended), в остальных <code>float64</code>
#     </span>

# %%
data['18_group'] = data['18_group'].fillna(0)
data['is_mi'] = data['is_mi'].fillna(0)
data['is_first_time'] = data['is_first_time'].fillna('')
data['17_group'] = data['17_group'].fillna(0)
data['blended'] = data['blended'].fillna('')
data['is_ml_student'] = data['is_ml_student'].fillna(0)

data
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
# your code
print("Всего ответов 'Нет':", (data['is_first_time'] == 'Нет').sum())
# Out:
# Всего ответов 'Нет': 51

# %%
(data['id'].duplicated() == True).sum() #количество строк, где ID повторяются
# Out:
# 14

# %% [markdown]
# <span style="color:green">
# | удалили дубликаты, оставили только последнее упоминание в dataframe (так можно, так как данные отсортированы по времени от раннего <br> | заполнения к позднему)
#     </span>

# %%
data1 = data.drop_duplicates(subset=['id'], keep='last').reset_index(drop=True)
data1
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 342 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 343 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 344 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 345 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 346 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# #### 4. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями (среди объединенных данных, ведь конкурс на каждый курс общий)?

# %%
# your code
print("Заявок 18 года:", (data1['18_group'] != 0).sum())
print("Заявок 17 года:", (data1['17_group'] != 0).sum())
print("Количество повторяющихся перцентилей:", (data1['percentile'].duplicated() == True).sum())
# Out:
# Заявок 18 года: 213
# Заявок 17 года: 134
# Количество повторяющихся перцентилей: 1

# %%
#просто полюбуемся какие перцентили повторяются
data1[data1['percentile'].duplicated(False) == True]
# Out:
#                   timestamp                                id  rating  \
# 78  2020-05-18 17:09:23.589  3e106aaef8b24dbb01319c73e14c2936     784
# 221 2020-05-14 21:52:43.844  3a7326c9e355a67d3805824ca34c4bc5    1457
#
#      18_group  is_mi                            fall_1  \
# 78      182.0    0.0  Безопасность компьютерных систем
# 221       0.0    0.0       Statistical Learning Theory
#
#                                 fall_2                       fall_3  \
# 78         Statistical Learning Theory         Матричные вычисления
# 221  Высокопроизводительные вычисления  Statistical Learning Theory
#
#                    spring_1                                     spring_2  \
# 78   Дискретная оптимизация  Промышленное программирование на языке Java
# 221   Символьные вычисления                             Численные методы
#
#                                        spring_3 is_first_time  percentile  \
# 78   Дополнительные главы прикладной статистики            Да         0.0
# ...

# %% [markdown]
# <span style="color:green">
# | Сумма студентов 18 и 17 года равна сумме строк dataframe - студентов без группы нет <br>
# | Так как есть только один повтор и мы знаем, что в столбце id значения не повторяются, то есть 2 студента с одним и тем же перцентилем, <br> | причем в разные года. Логично, что у студента ТОП-1 перцентиль будет 0 и он будет в каждом учебном году
#     </span>

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
data_blend = pd.DataFrame.from_dict({'count' : data1.groupby( ["blended"] ).size(), 'rating_mean': data1.groupby(["blended"])['rating'].mean()}).sort_values(by='count')
data_blend
# Out:
#                                        count  rating_mean
# blended
# Введение в дифференциальную геометрию     15  1210.733333
# Соревновательный анализ данных            32  1144.218750
# DevOps                                    87  1154.172414
#                                          213   633.901408

# %% [markdown]
# <span style="color:green">
# | Из предметов самым популярным оказался DevOps. Большинство студентов не указали blended-курс <br>
# | Самый высокий средний рейтинг у предмета "Введение в дифференциальную геометрию"
#     </span>

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
# your code
data_set = pd.DataFrame.from_dict({'count_subj': data1.groupby(['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']).size()}).reset_index()
data_set[data_set['count_subj'] > 1]
# Out:
#                                               fall_1  \
# 0                        Statistical Learning Theory
# 60             Байесовские методы машинного обучения
# 62             Байесовские методы машинного обучения
# 72                  Безопасность компьютерных систем
# 84                  Безопасность компьютерных систем
# 102                 Безопасность компьютерных систем
# 105                 Безопасность компьютерных систем
# 113                 Безопасность компьютерных систем
# 137                 Безопасность компьютерных систем
# 155                 Безопасность компьютерных систем
# 184                Высокопроизводительные вычисления
# 201                Высокопроизводительные вычисления
# 244                    Моделирование временных рядов
# 292  Сбор и обработка данных с помощью краудсорсинга
# 313                                         Язык SQL
#
#                                               fall_2  \
# 0                  Анализ неструктурированных данных
# ...

# %%
(data_set[data_set['count_subj'] > 1]).shape
# Out:
# (15, 8)

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# your code
'''df.melt(id_vars=['A'], value_vars=['B'],
        var_name='myVarname', value_name='myValname')
        source: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.melt.html'''

data_1817 = data1.melt(
    id_vars = ['18_group', '17_group'], 
    value_vars=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'], 
    value_name='subject').drop(columns = 'variable', axis=1).drop_duplicates().reset_index(drop = True)

data_1817
# Out:
#      18_group  17_group                                subject
# 0       181.0       0.0                               Язык SQL
# 1       181.0       0.0      Высокопроизводительные вычисления
# 2       185.0       0.0       Безопасность компьютерных систем
# 3       182.0       0.0            Statistical Learning Theory
# 4       183.0       0.0      Высокопроизводительные вычисления
# ..        ...       ...                                    ...
# 265       0.0     173.0         Соревновательный анализ данных
# 266       0.0     172.0         Соревновательный анализ данных
# 267       0.0     177.0  Введение в дифференциальную геометрию
# 268       0.0     174.0         Соревновательный анализ данных
# 269       0.0     174.0  Введение в дифференциальную геометрию
#
# [270 rows x 3 columns]

# %%
data_1817.loc[(data_1817['18_group'] != 0), '18_group'] = 1
data_1817.loc[(data_1817['17_group'] != 0), '17_group'] = 1
data_1817 = data_1817.drop_duplicates().groupby(['subject']).sum()
data_1817['sum'] = data_1817['18_group'] + data_1817['17_group']
data_1817
# Out:
#                                                     18_group  17_group  sum
# subject
#                                                          1.0       0.0  1.0
# DevOps                                                   0.0       1.0  1.0
# Statistical Learning Theory                              1.0       1.0  2.0
# Анализ данных в бизнесе                                  1.0       0.0  1.0
# Анализ неструктурированных данных                        0.0       1.0  1.0
# Байесовские методы машинного обучения                    0.0       1.0  1.0
# Безопасность компьютерных систем                         1.0       1.0  2.0
# Введение в дифференциальную геометрию                    0.0       1.0  1.0
# Высокопроизводительные вычисления                        1.0       1.0  2.0
# Генеративные модели в машинном обучении                  0.0       1.0  1.0
# Глубинное обучение в обработке звука                     0.0       1.0  1.0
# ...

# %%
data_1817[data_1817['sum'] == 2]
# Out:
#                                                     18_group  17_group  sum
# subject
# Statistical Learning Theory                              1.0       1.0  2.0
# Безопасность компьютерных систем                         1.0       1.0  2.0
# Высокопроизводительные вычисления                        1.0       1.0  2.0
# Моделирование временных рядов                            1.0       1.0  2.0
# Принятие решений в условиях риска и неопределён...       1.0       1.0  2.0
# Сбор и обработка данных с помощью краудсорсинга          1.0       1.0  2.0
# Численные методы                                         1.0       1.0  2.0

# %% [markdown]
# | 7 курсов брали студенты и в 17 и в 18 году

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# your code
a = data_1817[(data_1817['18_group'] == 1) & (data_1817['17_group'] == 0)]
b = data_1817[(data_1817['17_group'] == 1) & (data_1817['18_group'] == 0)]

# %%
a #курсы только 18 года
# Out:
#                                              18_group  17_group  sum
# subject
#                                                   1.0       0.0  1.0
# Анализ данных в бизнесе                           1.0       0.0  1.0
# Дискретная оптимизация                            1.0       0.0  1.0
# Дополнительные главы прикладной статистики        1.0       0.0  1.0
# Компьютерные сети                                 1.0       0.0  1.0
# Матричные вычисления                              1.0       0.0  1.0
# Машинное обучение 2                               1.0       0.0  1.0
# Промышленное программирование на языке Java       1.0       0.0  1.0
# Системы баз данных                                1.0       0.0  1.0
# Теория баз данных                                 1.0       0.0  1.0
# Язык SQL                                          1.0       0.0  1.0

# %%
b #курсы только 17 года
# Out:
#                                                     18_group  17_group  sum
# subject
# DevOps                                                   0.0       1.0  1.0
# Анализ неструктурированных данных                        0.0       1.0  1.0
# Байесовские методы машинного обучения                    0.0       1.0  1.0
# Введение в дифференциальную геометрию                    0.0       1.0  1.0
# Генеративные модели в машинном обучении                  0.0       1.0  1.0
# Глубинное обучение в обработке звука                     0.0       1.0  1.0
# Компьютерное зрение                                      0.0       1.0  1.0
# Конфликты и кооперация                                   0.0       1.0  1.0
# Методы сжатия и передачи медиаданных                     0.0       1.0  1.0
# Обучение с подкреплением                                 0.0       1.0  1.0
# Проектирование и разработка высоконагруженных с...       0.0       1.0  1.0
# ...

# %%
print("Всего курсов студенты взяли только в 18 году: ", a['sum'].count())
print("Всего курсов студенты взяли только в 17 году: ", b['sum'].count())
# Out:
# Всего курсов студенты взяли только в 18 году:  11
# Всего курсов студенты взяли только в 17 году:  13

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# your code

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 10, 7
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
data1
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 342 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 343 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 344 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 345 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 346 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %%
# your code
x

mean_rating = data1.groupby(['Date'])['rating'].mean().to_frame().reset_index()

plt.bar(mean_rating['Date'], mean_rating['rating'], color = 'lightblue')
plt.title('Гистограмма распределения ответов по дням')
plt.xlabel('Date')
plt.ylabel('count')
fig1 = plt.gcf()
plt.show()

# %%
#справочно что в себя включает средний рейтинг
mean_rating
# Out:
#          Date       rating
# 0  2020-05-14  1160.277778
# 1  2020-05-15   719.866667
# 2  2020-05-16   736.400000
# 3  2020-05-17   915.027027
# 4  2020-05-18   827.352679
# 5  2020-05-19   761.142857
# 6  2020-05-20   689.500000
# 7  2020-05-21   584.000000
# 8  2020-05-23  1080.500000
# 9  2020-05-24   670.500000

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code
fig1.savefig('hist_ratingMean.pdf')

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# <span style="color:red">!!!ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ!!!</span>
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем. </span>

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то на усмотрение проверяющего могут быть добавлены бонусные баллы. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
assert data1.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert data1.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе студента.

# %%
data1['cources_fall'] = ''

# %%
data1
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 342 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 343 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 344 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 345 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 346 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <br>
# **Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — fall_1 и fall_2, второй приоритет — fall_3. Такие студенты участвуют только в двух волнах отбора.**

# %%
# (￣^￣)ゞ
data1['cources_fall0'] = (data1['18_group'] + data1["17_group"]).astype(str) + " " + data1["is_mi"].astype(str)
data1['cources_fall0'].unique()
# Out:
# array(['181.0 0.0', '185.0 0.0', '182.0 0.0', '183.0 0.0', '187.0 0.0',
#        '186.0 0.0', '184.0 0.0', '188.0 0.0', '182.0 1.0', '184.0 1.0',
#        '185.0 1.0', '186.0 1.0', '188.0 1.0', '187.0 1.0', '172.0 0.0',
#        '176.0 0.0', '171.0 0.0', '175.0 0.0', '173.0 0.0', '174.0 0.0',
#        '177.0 0.0'], dtype=object)

# %%
#прописаны условия у кого 2, у остальных 1 курс по выбору
data1['cources_fall'] = [
    2 
    if ((x[6] == '1') & (x[1] == '8'))|(x[1:3] == '71')|(x[1:3] == '72')|(x[1:3] == '73')
    else 1
    for x in data1['cources_fall0']]

# %%
data1 = data1.drop(['cources_fall0'], axis=1)

# %%
data1
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 342 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 343 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 344 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 345 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 346 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# Проверка:

# %%
col_name = 'cources_fall'

assert(data1[data1['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(data1[data1['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(data1[data1['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(data1[data1['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# # 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
# Количество мест превращаю в датафрейм - далее понадобится
d = {'fall_1': ['Statistical Learning Theory', 
                'Высокопроизводительные вычисления', 
                'Анализ неструктурированных данных', 
                'Байесовские методы машинного обучения', 
                'Безопасность компьютерных систем', 
                'Глубинное обучение в обработке звука', 
                'Матричные вычисления', 
                'Моделирование временных рядов', 
                'Принятие решений в условиях риска и неопределённости', 
                'Сбор и обработка данных с помощью краудсорсинга', 
                'Теория баз данных', 
                'Язык SQL'], 'places': [60, 60, 999, 30, 30, 30, 30, 30, 30, 30, 30, 30,]}
courses = pd.DataFrame(data=d)
courses
# Out:
#                                                fall_1  places
# 0                         Statistical Learning Theory      60
# 1                   Высокопроизводительные вычисления      60
# 2                   Анализ неструктурированных данных     999
# 3               Байесовские методы машинного обучения      30
# 4                    Безопасность компьютерных систем      30
# 5                Глубинное обучение в обработке звука      30
# 6                                Матричные вычисления      30
# 7                       Моделирование временных рядов      30
# 8   Принятие решений в условиях риска и неопределё...      30
# 9     Сбор и обработка данных с помощью краудсорсинга      30
# 10                                  Теория баз данных      30
# 11                                           Язык SQL      30

# %%
#создадим итоговый датафрейм (в него будем подтягивать)
df_fall = data1[['id', 'percentile']].copy().sort_values(by = 'percentile').reset_index(drop=True)
df_fall
# Out:
#                                    id  percentile
# 0    3e106aaef8b24dbb01319c73e14c2936    0.000000
# 1    3a7326c9e355a67d3805824ca34c4bc5    0.000000
# 2    e0ca1a9548af9a3f98428c62420aa484    0.004484
# 3    7fe7df0d207babbf30249b3063ac1f26    0.007246
# 4    86d929f6fd741e56e93cee5900298849    0.008969
# ..                                ...         ...
# 342  79d14db48e4737af731960ae212d5134    0.985507
# 343  40b18d40197e3db66312a026e06b8ff1    0.986547
# 344  be4fa2120de3397ae21eac38ff0060e3    0.991031
# 345  d539461bf254cf8b3201cdf7990b119e    0.992754
# 346  7a21ef645ecb42198be493dd65320e78    0.995516
#
# [347 rows x 2 columns]

# %% [markdown]
# По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <br>
# **Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — fall_1 и fall_2, второй приоритет — fall_3. Такие студенты участвуют только в двух волнах отбора.**

# %%
# (￣^￣)ゞ

#смотрю сколько студентов попадает на курсы, которые выбрал первым приоритетом (превышает кол-во мест на курсе)

df_fall1_places = data1.groupby(['fall_1'])['id'].size().to_frame().sort_values(by = 'fall_1').reset_index()
df_fall1_places
# Out:
#                                                fall_1   id
# 0                         Statistical Learning Theory   25
# 1                   Анализ неструктурированных данных   32
# 2               Байесовские методы машинного обучения   16
# 3                    Безопасность компьютерных систем  110
# 4                   Высокопроизводительные вычисления   41
# 5                Глубинное обучение в обработке звука   10
# 6                                Матричные вычисления   14
# 7                       Моделирование временных рядов   22
# 8   Принятие решений в условиях риска и неопределё...    5
# 9     Сбор и обработка данных с помощью краудсорсинга   34
# 10                                  Теория баз данных   11
# 11                                           Язык SQL   27

# %%
#создаем сводную со перцентилем, курсом первого приоритета и id студента
# percentile понадобится для сортировки и отсеивания по времени 
#  (если какой-то курс поставило первым приоритетом больше студентов чем мест на нем)

df_fall1 = data1.groupby(['fall_1', 'id', 'percentile']).size().to_frame().sort_values(by = ['fall_1', 'percentile']).reset_index().drop(columns = 0)
df_fall1
# Out:
#                           fall_1                                id  percentile
# 0    Statistical Learning Theory  3a7326c9e355a67d3805824ca34c4bc5    0.000000
# 1    Statistical Learning Theory  723d5f32b699c971b4095a017c883ffa    0.017937
# 2    Statistical Learning Theory  1f63fc485d851236249263b91dc03d6b    0.031390
# 3    Statistical Learning Theory  e4caca755ee0bdd711e18fb8084958b5    0.103139
# 4    Statistical Learning Theory  fc833a2815fa010d53b0047244438d9d    0.144928
# ..                           ...                               ...         ...
# 342                     Язык SQL  3de75278c0cdb78bbe54267f65c67d25    0.811659
# 343                     Язык SQL  162cbdeec1b766ab857df93cdf9d65f4    0.852018
# 344                     Язык SQL  cfe9fd28e4cbe0b46594b21f3067e30a    0.856502
# 345                     Язык SQL  a19f36ae8465cac527e8ce7b6ebf1213    0.901345
# 346                     Язык SQL  ab5248060fbaac411a79a62dfb0d263d    0.946188
#
# [347 rows x 3 columns]

# %% [markdown]
# Осенние курсы: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)

# %%
#создаю dataframes по каждому предмету и обрезаю на нужное количество мест (30-60-infty)
#делаю влоб лучше пока не продумано
computer_systems_security = df_fall1[df_fall1['fall_1'] == 'Безопасность компьютерных систем'].head(30)
vychislenia = df_fall1[df_fall1['fall_1'] == 'Высокопроизводительные вычисления'].head(60)
crowdsource = df_fall1[df_fall1['fall_1'] == 'Сбор и обработка данных с помощью краудсорсинга'].head(30)
unstructured = df_fall1[df_fall1['fall_1'] == 'Анализ неструктурированных данных']
sql = df_fall1[df_fall1['fall_1'] == 'Язык SQL'].head(30)
Statistical_Learning_Theory = df_fall1[df_fall1['fall_1'] == 'Statistical Learning Theory'].head(60)
time_series = df_fall1[df_fall1['fall_1'] == 'Моделирование временных рядов'].head(30)
Baes = df_fall1[df_fall1['fall_1'] == 'Байесовские методы машинного обучения'].head(30)
matrix = df_fall1[df_fall1['fall_1'] == 'Матричные вычисления'].head(30)
databases = df_fall1[df_fall1['fall_1'] == 'Теория баз данных'].head(30)
deep_learning = df_fall1[df_fall1['fall_1'] == 'Глубинное обучение в обработке звука'].head(30)
not_sure_decisions = df_fall1[df_fall1['fall_1'] == 'Принятие решений в условиях риска и неопределённости'].head(30)

# %%
# соединяю обратно все dataframes
all_fall_1 = pd.concat([computer_systems_security, 
                            vychislenia, crowdsource, 
                            unstructured, 
                            sql, 
                            Statistical_Learning_Theory, 
                            time_series, 
                            Baes, 
                            matrix, 
                            databases, 
                            deep_learning, 
                            not_sure_decisions], names=['fall_1'], ignore_index=True)

all_fall_1
# Out:
#                                                 fall_1  \
# 0                     Безопасность компьютерных систем
# 1                     Безопасность компьютерных систем
# 2                     Безопасность компьютерных систем
# 3                     Безопасность компьютерных систем
# 4                     Безопасность компьютерных систем
# ..                                                 ...
# 258  Принятие решений в условиях риска и неопределё...
# 259  Принятие решений в условиях риска и неопределё...
# 260  Принятие решений в условиях риска и неопределё...
# 261  Принятие решений в условиях риска и неопределё...
# 262  Принятие решений в условиях риска и неопределё...
#
#                                    id  percentile
# 0    3e106aaef8b24dbb01319c73e14c2936    0.000000
# 1    bfe75c08c6b7e31d4e7d48c9c5fed69b    0.022422
# 2    04f9a2dd035a040318ecd064959df3a0    0.026906
# 3    bb29d9b9230528a4873f91abce2095b8    0.036232
# ...

# %%
# добавляю в df_fall - она у нас и будет итоговой (в нее подтянем)
df_fall = df_fall.merge(all_fall_1[['fall_1', 'id']], how = 'left', on = 'id').rename(columns = {'fall_1': 'course1'})

# %%
df_fall
# Out:
#                                    id  percentile  \
# 0    3e106aaef8b24dbb01319c73e14c2936    0.000000
# 1    3a7326c9e355a67d3805824ca34c4bc5    0.000000
# 2    e0ca1a9548af9a3f98428c62420aa484    0.004484
# 3    7fe7df0d207babbf30249b3063ac1f26    0.007246
# 4    86d929f6fd741e56e93cee5900298849    0.008969
# ..                                ...         ...
# 342  79d14db48e4737af731960ae212d5134    0.985507
# 343  40b18d40197e3db66312a026e06b8ff1    0.986547
# 344  be4fa2120de3397ae21eac38ff0060e3    0.991031
# 345  d539461bf254cf8b3201cdf7990b119e    0.992754
# 346  7a21ef645ecb42198be493dd65320e78    0.995516
#
#                                                course1
# 0                     Безопасность компьютерных систем
# 1                          Statistical Learning Theory
# 2                                 Матричные вычисления
# 3                    Высокопроизводительные вычисления
# 4      Сбор и обработка данных с помощью краудсорсинга
# ...

# %% [markdown]
# логика: сначала выбираются студенты по fall_1 (попадают на курс только те, у кого меньше перцентиль), потом по fall_2
# в случае, если студент поставил курс на fall_1, а другой студент на fall_2, то даже если у студента, кто выбрал курс fall_2, ниже перцентиль - приоритет все равно тому, кто выбрал еэтот курс как fall_1

# %% [markdown]
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).

# %%
# считаю сколько мест осталось для fall_2
df_fall2_places = courses.copy()

df_help = all_fall_1.groupby('fall_1').size().to_frame().reset_index()

df_fall2_places = df_fall2_places.merge(df_help, how = 'left', on = 'fall_1')

df_fall2_places['rest_for_fall_2'] = df_fall2_places['places'] - df_fall2_places[0] 
df_fall2_places = df_fall2_places.drop(columns = ['places', 0])
df_fall2_places
# Out:
#                                                fall_1  rest_for_fall_2
# 0                         Statistical Learning Theory               35
# 1                   Высокопроизводительные вычисления               19
# 2                   Анализ неструктурированных данных              967
# 3               Байесовские методы машинного обучения               14
# 4                    Безопасность компьютерных систем                0
# 5                Глубинное обучение в обработке звука               20
# 6                                Матричные вычисления               16
# 7                       Моделирование временных рядов                8
# 8   Принятие решений в условиях риска и неопределё...               25
# 9     Сбор и обработка данных с помощью краудсорсинга                0
# 10                                  Теория баз данных               19
# 11                                           Язык SQL                3

# %%
# фильтрую id, у которых первый приоритет включает и fall_1 и fall_2
id_with_2_courses = data1.groupby(['id', 'cources_fall', 'fall_2', 'percentile']).size().to_frame().reset_index().drop(columns = 0)
id_with_2_courses = id_with_2_courses[id_with_2_courses['cources_fall'] == 2].reset_index(drop = True)
#подгружаю по id столбец "course" из df_fall, чтобы по нему отсортирвать ребят, у кого еще нет курса первого приоритета
df_fall_2_filtered = id_with_2_courses.merge(df_fall[['id', 'course1']], how = 'left', on = 'id')
df_fall_2_filtered = df_fall_2_filtered[df_fall_2_filtered['course1'].isnull()].reset_index(drop = True)[['id', 'fall_2', 'percentile']].sort_values(
    by = ['fall_2', 'percentile'])
df_fall_2_filtered
# Out:
#                                   id  \
# 7   b75b5f8abebf7faf4adbb6247d6d03bb
# 2   492c677be00bb8223ebbaffa3aff2549
# 6   881b1a6fda195b354ae2edb396a69f5d
# 11  eb1d7205d913319ef3d48e0719839849
# 5   7fcf56aae6836855a689000a50e80360
# 3   71c8f779c794a59d749092a11a350557
# 10  d555d2805e1d93d4f023e57dc4c8f403
# 4   79d14db48e4737af731960ae212d5134
# 8   c154bbf18efdd4d760e52155eaa87929
# 1   39cd1820459fdbcc193f9bb0ddb74a58
# 9   d40cbae8cfc9e6c5d05831ef7e122f3e
# 0   0c0cbdd1a309c1d1fd8993c4dc907bb5
# 12  feb53dcdd28fff9dc4a981c3419fea6f
#
#                                                fall_2  percentile
# 7                         Statistical Learning Theory    0.695067
# 2                   Анализ неструктурированных данных    0.260870
# 6                   Анализ неструктурированных данных    0.782609
# 11              Байесовские методы машинного обучения    0.608696
# 5                    Безопасность компьютерных систем    0.536232
# ...

# %%
df_fall2_places
# Out:
#                                                fall_1  rest_for_fall_2
# 0                         Statistical Learning Theory               35
# 1                   Высокопроизводительные вычисления               19
# 2                   Анализ неструктурированных данных              967
# 3               Байесовские методы машинного обучения               14
# 4                    Безопасность компьютерных систем                0
# 5                Глубинное обучение в обработке звука               20
# 6                                Матричные вычисления               16
# 7                       Моделирование временных рядов                8
# 8   Принятие решений в условиях риска и неопределё...               25
# 9     Сбор и обработка данных с помощью краудсорсинга                0
# 10                                  Теория баз данных               19
# 11                                           Язык SQL                3

# %%
#создаю dataframes по каждому предмету и обрезаю на нужное количество мест (30-60-infty)
#делаю влоб лучше пока не продумано - обрезаю по информации из df_fall2_places

fall_2_Statistical_Learning_Theory = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Statistical Learning Theory'].head(35)
fall_2_unstructured = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Анализ неструктурированных данных']
fall_2_Baes = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Байесовские методы машинного обучения'].head(14)
fall_2_computer_systems_security = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Безопасность компьютерных систем'].head(0)
fall_2_vychislenia = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Высокопроизводительные вычисления'].head(19)
fall_2_deep_learning = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Глубинное обучение в обработке звука'].head(20)
fall_2_matrix = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Матричные вычисления'].head(16)
fall_2_time_series = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Моделирование временных рядов'].head(8)
fall_2_not_sure_decisions = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Принятие решений в условиях риска и неопределённости'].head(25)
fall_2_crowdsource = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Сбор и обработка данных с помощью краудсорсинга'].head(0)
fall_2_databases = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Теория баз данных'].head(19)
fall_2_sql = df_fall_2_filtered[df_fall_2_filtered['fall_2'] == 'Язык SQL'].head(3)

# соединяю датафреймы
all_fall_2_filtered = pd.concat([fall_2_computer_systems_security, 
                                       fall_2_vychislenia, 
                                       fall_2_crowdsource, 
                                       fall_2_unstructured, 
                                       fall_2_sql, 
                                       fall_2_Statistical_Learning_Theory, 
                                       fall_2_time_series, 
                                       fall_2_Baes, 
                                       fall_2_matrix, 
                                       fall_2_databases, 
                                       fall_2_deep_learning, 
                                       fall_2_not_sure_decisions], 
                                      names=['fall_2'], 
                                      ignore_index=True).sort_values(by = 'fall_2')
all_fall_2_filtered = all_fall_2_filtered.reset_index(drop = True)

all_fall_2_filtered
# Out:
#                                  id  \
# 0  b75b5f8abebf7faf4adbb6247d6d03bb
# 1  492c677be00bb8223ebbaffa3aff2549
# 2  881b1a6fda195b354ae2edb396a69f5d
# 3  eb1d7205d913319ef3d48e0719839849
# 4  71c8f779c794a59d749092a11a350557
# 5  d555d2805e1d93d4f023e57dc4c8f403
# 6  79d14db48e4737af731960ae212d5134
# 7  feb53dcdd28fff9dc4a981c3419fea6f
#
#                                               fall_2  percentile
# 0                        Statistical Learning Theory    0.695067
# 1                  Анализ неструктурированных данных    0.260870
# 2                  Анализ неструктурированных данных    0.782609
# 3              Байесовские методы машинного обучения    0.608696
# 4               Глубинное обучение в обработке звука    0.601449
# 5               Глубинное обучение в обработке звука    0.963768
# 6  Принятие решений в условиях риска и неопределё...    0.985507
# 7                                           Язык SQL    0.968610

# %%
# прицепим этих ребят в df
df_fall = df_fall.merge(all_fall_2_filtered[['id', 'fall_2']], on = 'id', how = 'left')

# %%
# добавим в course1 ребят из fall_2 (с двумя курсами), которые поместились в выбранные курсы
df_fall = df_fall.fillna('')
df_fall['course1'] = df_fall['course1'].astype(str) + df_fall['fall_2'].astype(str) 
df_fall = df_fall.drop(columns = 'fall_2')
df_fall
# Out:
#                                    id  percentile  \
# 0    3e106aaef8b24dbb01319c73e14c2936    0.000000
# 1    3a7326c9e355a67d3805824ca34c4bc5    0.000000
# 2    e0ca1a9548af9a3f98428c62420aa484    0.004484
# 3    7fe7df0d207babbf30249b3063ac1f26    0.007246
# 4    86d929f6fd741e56e93cee5900298849    0.008969
# ..                                ...         ...
# 342  79d14db48e4737af731960ae212d5134    0.985507
# 343  40b18d40197e3db66312a026e06b8ff1    0.986547
# 344  be4fa2120de3397ae21eac38ff0060e3    0.991031
# 345  d539461bf254cf8b3201cdf7990b119e    0.992754
# 346  7a21ef645ecb42198be493dd65320e78    0.995516
#
#                                                course1
# 0                     Безопасность компьютерных систем
# 1                          Statistical Learning Theory
# 2                                 Матричные вычисления
# 3                    Высокопроизводительные вычисления
# 4      Сбор и обработка данных с помощью краудсорсинга
# ...

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
df_help_min = df_fall.groupby(['course1'])['percentile'].min().to_frame().reset_index().drop(0)
df_help_min
# Out:
#                                               course1  percentile
# 1                         Statistical Learning Theory    0.000000
# 2                   Анализ неструктурированных данных    0.050725
# 3               Байесовские методы машинного обучения    0.014493
# 4                    Безопасность компьютерных систем    0.000000
# 5                   Высокопроизводительные вычисления    0.007246
# 6                Глубинное обучение в обработке звука    0.079710
# 7                                Матричные вычисления    0.004484
# 8                       Моделирование временных рядов    0.107623
# 9   Принятие решений в условиях риска и неопределё...    0.542601
# 10    Сбор и обработка данных с помощью краудсорсинга    0.008969
# 11                                  Теория баз данных    0.035874
# 12                                           Язык SQL    0.183857

# %%
df_help_max = df_fall.groupby(['course1'])['percentile'].max().to_frame().reset_index().drop(0)
df_help_max
# Out:
#                                               course1  percentile
# 1                         Statistical Learning Theory    0.973094
# 2                   Анализ неструктурированных данных    0.992754
# 3               Байесовские методы машинного обучения    0.905797
# 4                    Безопасность компьютерных систем    0.215247
# 5                   Высокопроизводительные вычисления    0.919283
# 6                Глубинное обучение в обработке звука    0.963768
# 7                                Матричные вычисления    0.932735
# 8                       Моделирование временных рядов    0.874439
# 9   Принятие решений в условиях риска и неопределё...    0.995516
# 10    Сбор и обработка данных с помощью краудсорсинга    0.905830
# 11                                  Теория баз данных    0.923767
# 12                                           Язык SQL    0.968610

# %%
df_fall_add = df_fall.merge(df_help_max, on = 'course1', how = 'left')
df_fall_add = df_fall_add.merge(df_help_min, on = 'course1', how = 'left')
df_fall_add
# Out:
#                                    id  percentile_x  \
# 0    3e106aaef8b24dbb01319c73e14c2936      0.000000
# 1    3a7326c9e355a67d3805824ca34c4bc5      0.000000
# 2    e0ca1a9548af9a3f98428c62420aa484      0.004484
# 3    7fe7df0d207babbf30249b3063ac1f26      0.007246
# 4    86d929f6fd741e56e93cee5900298849      0.008969
# ..                                ...           ...
# 342  79d14db48e4737af731960ae212d5134      0.985507
# 343  40b18d40197e3db66312a026e06b8ff1      0.986547
# 344  be4fa2120de3397ae21eac38ff0060e3      0.991031
# 345  d539461bf254cf8b3201cdf7990b119e      0.992754
# 346  7a21ef645ecb42198be493dd65320e78      0.995516
#
#                                                course1  percentile_y  \
# 0                     Безопасность компьютерных систем      0.215247
# 1                          Statistical Learning Theory      0.973094
# 2                                 Матричные вычисления      0.932735
# ...

# %%
df_fall_add['is_first_place'] = ''
for i in range(len(df_fall_add)):
    if df_fall_add['percentile_x'][i] == df_fall_add['percentile'][i]:
        df_fall_add['is_first_place'][i] = True
    else:
        df_fall_add['is_first_place'][i] = np.nan

df_fall_add
# Out:
# <ipython-input-873-e5ddfe9baf96>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fall_add['is_first_place'][i] = True
# <ipython-input-873-e5ddfe9baf96>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fall_add['is_first_place'][i] = np.nan
#                                    id  percentile_x  \
# 0    3e106aaef8b24dbb01319c73e14c2936      0.000000
# 1    3a7326c9e355a67d3805824ca34c4bc5      0.000000
# 2    e0ca1a9548af9a3f98428c62420aa484      0.004484
# 3    7fe7df0d207babbf30249b3063ac1f26      0.007246
# 4    86d929f6fd741e56e93cee5900298849      0.008969
# ...

# %%
df_fall_add['is_last_place'] = ''
for i in range(len(df_fall_add)):
    if df_fall_add['percentile_x'][i] == df_fall_add['percentile_y'][i]:
        df_fall_add['is_last_place'][i] = True
    else:
        df_fall_add['is_last_place'][i] = np.nan

df_fall_add
# Out:
# <ipython-input-875-c75a8eb0c30f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fall_add['is_last_place'][i] = np.nan
# <ipython-input-875-c75a8eb0c30f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fall_add['is_last_place'][i] = True
#                                    id  percentile_x  \
# 0    3e106aaef8b24dbb01319c73e14c2936      0.000000
# 1    3a7326c9e355a67d3805824ca34c4bc5      0.000000
# 2    e0ca1a9548af9a3f98428c62420aa484      0.004484
# 3    7fe7df0d207babbf30249b3063ac1f26      0.007246
# 4    86d929f6fd741e56e93cee5900298849      0.008969
# ...

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = 'is_first_place'      # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'    # insert name of your new column with is_last_place as str


assert((data_finish[data_finish[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((data_finish[data_finish[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-878-f3f762cac18b> in <module>
#       3
#       4
# ----> 5 assert((data_finish[data_finish[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       6         ==
#       7         check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      27     @unpack_zerodim_and_defer("__eq__")
#      28     def __eq__(self, other):
# ---> 29         return self._cmp_method(other, operator.eq)
#      30
# ...

# %%
df_fall_add.to_csv('res_fall.csv')

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
# (￣^￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/40211/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
# (￣^'￣)ゞ

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/40211/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %% [markdown]
# <img src="https://c.tenor.com/LShq6sF99qsAAAAd/rachel-rachel-green.gif" style="width: 400px">

# %% [markdown]
# <img src="https://c.tenor.com/DR6LSyyHWNwAAAAd/friends-claude.gif" style="width: 400px">
# <img src="https://c.tenor.com/KoPOvbo-8VUAAAAC/unagi-ross.gif" style="width: 400px">

# %% [markdown]
# <img src="https://c.tenor.com/069uIv5CW-UAAAAd/friends-how-you-doin.gif" style="width: 400px">
