# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Машинное-обучение,-ФКН-ВШЭ" data-toc-modified-id="Машинное-обучение,-ФКН-ВШЭ-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Машинное обучение, ФКН ВШЭ</a></span><ul class="toc-item"><li><span><a href="#Практическое-задание-4.-Классификация" data-toc-modified-id="Практическое-задание-4.-Классификация-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Практическое задание 4. Классификация</a></span><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#О-задании" data-toc-modified-id="О-задании-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>О задании</a></span><ul class="toc-item"><li><span><a href="#Самостоятельная-оценка-результатов" data-toc-modified-id="Самостоятельная-оценка-результатов-1.1.2.1"><span class="toc-item-num">1.1.2.1&nbsp;&nbsp;</span>Самостоятельная оценка результатов</a></span></li></ul></li><li><span><a href="#Оценивание-и-штрафы" data-toc-modified-id="Оценивание-и-штрафы-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Оценивание и штрафы</a></span></li><li><span><a href="#Формат-сдачи" data-toc-modified-id="Формат-сдачи-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Формат сдачи</a></span></li></ul></li></ul></li><li><span><a href="#Часть-1.-SVM,-LR-и-калибровка-вероятностей-(--2-балла--)" data-toc-modified-id="Часть-1.-SVM,-LR-и-калибровка-вероятностей-(--2-балла--)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Часть 1. SVM, LR и калибровка вероятностей (--2 балла--)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Задание-1.1--Сравнение-методов-(0.5-балла)" data-toc-modified-id="Задание-1.1--Сравнение-методов-(0.5-балла)-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span><strong>Задание 1.1  Сравнение методов</strong> (0.5 балла)</a></span></li><li><span><a href="#Задание-1.2.-Визуализация-в-подходах-SVM,-LR-(0.5-балла)" data-toc-modified-id="Задание-1.2.-Визуализация-в-подходах-SVM,-LR-(0.5-балла)-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span><strong>Задание 1.2. Визуализация в подходах SVM, LR</strong> (0.5 балла)</a></span></li><li><span><a href="#Задание-2.-Калибровка-вероятностей-(1-балл)" data-toc-modified-id="Задание-2.-Калибровка-вероятностей-(1-балл)-2.0.0.3"><span class="toc-item-num">2.0.0.3&nbsp;&nbsp;</span><strong>Задание 2. Калибровка вероятностей</strong> (1 балл)</a></span><ul class="toc-item"><li><span><a href="#Бонус:-Авторское-решение-(0.5-балла)" data-toc-modified-id="Бонус:-Авторское-решение-(0.5-балла)-2.0.0.3.1"><span class="toc-item-num">2.0.0.3.1&nbsp;&nbsp;</span><strong>Бонус: Авторское решение</strong> (<del>0.5 балла</del>)</a></span></li></ul></li></ul></li></ul></li></ul></li><li><span><a href="#Часть-2.-Обработка-категориальных-переменных-(--4-балла--)" data-toc-modified-id="Часть-2.-Обработка-категориальных-переменных-(--4-балла--)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Часть 2. Обработка категориальных переменных (--4 балла--)</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span><strong>Подготовка данных</strong></a></span></li><li><span><a href="#Задание-3.-OrdinalEncoder--(0.5-балла)" data-toc-modified-id="Задание-3.-OrdinalEncoder--(0.5-балла)-3.0.0.2"><span class="toc-item-num">3.0.0.2&nbsp;&nbsp;</span><strong>Задание 3. OrdinalEncoder</strong>  (0.5 балла)</a></span></li><li><span><a href="#Задание-4.-One-Hot-Encoding-(0.5-балла)" data-toc-modified-id="Задание-4.-One-Hot-Encoding-(0.5-балла)-3.0.0.3"><span class="toc-item-num">3.0.0.3&nbsp;&nbsp;</span><strong>Задание 4. One-Hot Encoding</strong> (0.5 балла)</a></span></li><li><span><a href="#Задание-5.-Mean-target-Encoding-(1-балл)" data-toc-modified-id="Задание-5.-Mean-target-Encoding-(1-балл)-3.0.0.4"><span class="toc-item-num">3.0.0.4&nbsp;&nbsp;</span><strong>Задание 5. Mean-target Encoding</strong> (1 балл)</a></span><ul class="toc-item"><li><span><a href="#Бонус:-Эффективная-реализация-(1-балл)" data-toc-modified-id="Бонус:-Эффективная-реализация-(1-балл)-3.0.0.4.1"><span class="toc-item-num">3.0.0.4.1&nbsp;&nbsp;</span><strong>Бонус: Эффективная реализация (1 балл)</strong></a></span></li></ul></li><li><span><a href="#Задание-6.-Пошумим--(0.5-балла)" data-toc-modified-id="Задание-6.-Пошумим--(0.5-балла)-3.0.0.5"><span class="toc-item-num">3.0.0.5&nbsp;&nbsp;</span><strong>Задание 6. Пошумим</strong>  (0.5 балла)</a></span><ul class="toc-item"><li><span><a href="#Бонус:-другой-подход-(0.5-балла)" data-toc-modified-id="Бонус:-другой-подход-(0.5-балла)-3.0.0.5.1"><span class="toc-item-num">3.0.0.5.1&nbsp;&nbsp;</span><strong>Бонус: другой подход</strong> (0.5 балла)</a></span></li></ul></li><li><span><a href="#Задание-7.-Сглаживание-счетчиков--(1-балл)" data-toc-modified-id="Задание-7.-Сглаживание-счетчиков--(1-балл)-3.0.0.6"><span class="toc-item-num">3.0.0.6&nbsp;&nbsp;</span><strong>Задание 7. Сглаживание счетчиков</strong>  (1 балл)</a></span></li><li><span><a href="#Задание-8.-И-все-таки-числовой?--(0.5-балла)" data-toc-modified-id="Задание-8.-И-все-таки-числовой?--(0.5-балла)-3.0.0.7"><span class="toc-item-num">3.0.0.7&nbsp;&nbsp;</span><strong>Задание 8. И все-таки числовой?</strong>  (0.5 балла)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Часть-3.-Отбор-признаков" data-toc-modified-id="Часть-3.-Отбор-признаков-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Часть 3. Отбор признаков</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Задание-9.-Встроенные-методы-(0.5-балла)" data-toc-modified-id="Задание-9.-Встроенные-методы-(0.5-балла)-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span><strong>Задание 9. Встроенные методы (0.5 балла)</strong></a></span></li><li><span><a href="#Задание-10.-Методы-фильтрации-(0.5-балла)" data-toc-modified-id="Задание-10.-Методы-фильтрации-(0.5-балла)-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span><strong>Задание 10. Методы фильтрации (0.5 балла)</strong></a></span></li><li><span><a href="#Задание-11.-Методы-обёртки-(1-балл)" data-toc-modified-id="Задание-11.-Методы-обёртки-(1-балл)-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span><strong>Задание 11. Методы-обёртки</strong> (1 балл)</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Часть-4.-Оценка-экономического-эффекта-модели" data-toc-modified-id="Часть-4.-Оценка-экономического-эффекта-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Часть 4. Оценка экономического эффекта модели</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Задание-12.-Прогноз-по-доходам-и-расходам-(1-балл)" data-toc-modified-id="Задание-12.-Прогноз-по-доходам-и-расходам-(1-балл)-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span><strong>Задание 12. Прогноз по доходам и расходам</strong> (1 балл)</a></span></li><li><span><a href="#Задание-13.-Ключевая-метрика-(1-балл)" data-toc-modified-id="Задание-13.-Ключевая-метрика-(1-балл)-5.0.0.2"><span class="toc-item-num">5.0.0.2&nbsp;&nbsp;</span><strong>Задание 13. Ключевая метрика</strong> (1 балл)</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Машинное обучение, ФКН ВШЭ
#
# ## Практическое задание 4. Классификация

# %% [markdown]
# ### Общая информация
# Дата выдачи: 04.11.2022
#
# Мягкий дедлайн: 23:59MSK 16.11.2022
#
# Жесткий дедлайн: 23:59MSK 23.11.2022

# %% [markdown]
# ### О задании
#
# В этом задании вы:
# - ознакомитесь с тем, что происходит "внутри" метода опорных векторов и логистической регрессии
# - познакомитесь с калибровкой вероятности
# - изучите методы трансформации переменных и методы отбора признаков
# - попробуете оценить экономический эффект модели
#
# ----
#
# #### Самостоятельная оценка результатов
#
# Для удобства проверки, исходя из набора решенных задач, посчитайте свою максимальную оценку.
#
# **Оценка**: 8,5

# %% [markdown]
# ### Оценивание и штрафы

# %% [markdown]
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после указанного жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.

# %% [markdown]
# ### Формат сдачи

# %% [markdown]
# Для сдачи задания переименуйте получившийся файл *.ipynb в соответствии со следующим форматом: homework-practice-04-linclass-__Username__.ipynb, где Username — ваша фамилия и имя на латинице именно в таком порядке (например, homework-practice-04-linclass-__IvanovIvan__.ipynb).

# %% [markdown]
# # Часть 1. SVM, LR и калибровка вероятностей (--2 балла--)

# %%
# !pip install --upgrade scikit-learn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# #### __Задание 1.1  Сравнение методов__ (0.5 балла)

# %% [markdown]
# Сгенерируем синтетические данные.

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# фиксируем random_state для воспроизводимости результатов
X, y = make_classification(
    n_samples=10000, n_features=10, n_informative=5, n_redundant=5, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# __Случайный классификатор__
#
# Для начала зададим самую простую модель, которая на каждом объекте выдаёт один из двух классов с равными вероятностями. По тестовой выборке вычислим AUC-ROC, AUC-PR.

# %%
np.random.seed(42)

# наш случайный классификатор
y_random = np.random.choice([0, 1], size=len(y_test), p=[0.5, 0.5])
y_random
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %% [markdown]
# *Ниже приведен **пример** работы* со встроенными функциями `sklearn` для отрисовки ROC и PR кривых, сохранения метрик. Пайплайн можно изменять как вам удобно, за особенно эффективные или красивые варианты может быть начислен небольшой бонус :)

# %%
from sklearn.metrics import auc
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay

from sklearn.metrics import roc_auc_score
from sklearn.metrics import RocCurveDisplay
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc, precision_recall_curve, make_scorer, roc_auc_score, roc_curve
from sklearn.calibration import CalibratedClassifierCV
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer


pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.options.mode.chained_assignment = None
# %config InlineBackend.figure_format='retina'

# %%
fig, ax = plt.subplots(1, 2, figsize=(11, 5))

PrecisionRecallDisplay.from_predictions(y_test, y_random, ax=ax[0])
precision, recall, _ = precision_recall_curve(y_test, y_random)
print('AUC-PR: %.5f' % auc(recall, precision))
ax[0].set_title("PRC for Random Classifier")
ax[0].set_ylim(0, 1.1)

RocCurveDisplay.from_predictions(y_test, y_random, ax=ax[1])
print('AUC-ROC: %.5f' % roc_auc_score(y_test, y_random))
ax[1].set_title("ROC for Random Classifier")
ax[1].set_ylim(0, 1.1)

plt.tight_layout()
# Out:
# AUC-PR: 0.63340
# AUC-ROC: 0.50394

# %%
# dataframe для сравнения 
# методов классификации по метрикам
df_metrics = pd.DataFrame(columns=['AUC_PR', 'AUC_ROC', 'reg_const'])

# добавление очередной строки с характеристиками метода
df_metrics.loc['Random Classifier'] = [
    auc(recall, precision),
    roc_auc_score(y_test, y_random),
    None
]

# по аналогии результаты следующих экспериментов можно будет собрать в табличку
df_metrics
# Out:
#                      AUC_PR   AUC_ROC  reg_const
# Random Classifier  0.633402  0.503944        NaN

# %% [markdown]
# __Support Vector Machine (Linear Kernel)__
#
# Обучите метод опорных векторов. На занятиях мы проходили линейный вариант без ядрового перехода, что соответствует линейному ядру (`LinearSVC` или же `SVC(kernel='linear')` в `sklearn.svm`). Подберите параметр регуляризации `C` (можете воспользоваться кросс-валидацией или отделить валидационную выборку от обучающей).
#
# __NB!__ Здесь и далее, если не сказано иначе, подбирайте __оптимальные гиперпараметры с точки зрения AUC-PR.__

# %%
def AUC_PR(y_true, y_pred_proba, return_pr=False):
    precision, recall, thresholds = precision_recall_curve(y_true, y_pred_proba)
    auc_pr = auc(recall, precision)

    if return_pr:
        return auc_pr, precision, recall
    else:
        return auc_pr

auc_pr_score = make_scorer(AUC_PR, greater_is_better=True, needs_proba=True)

# %%
svc = SVC(kernel='linear', probability=True)
grid_search = GridSearchCV(svc, param_grid={'C' : [1e-04, 1e-03, 1e-02, 0.05, 0.1]}, scoring=auc_pr_score, n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=SVC(kernel='linear', probability=True), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.05, 0.1]},
#              scoring=make_scorer(AUC_PR, needs_proba=True))

# %%
print('GridSearch CV best score : {:.4f}'.format(grid_search.best_score_))
print('Parameters that give the best results :', (grid_search.best_params_))
print('\nEstimator that was chosen by the search :', (grid_search.best_estimator_))
# Out:
# GridSearch CV best score : 0.8277
# Parameters that give the best results : {'C': 0.0001}
#
# Estimator that was chosen by the search : SVC(C=0.0001, kernel='linear', probability=True)

# %%
fig, ax = plt.subplots(1, figsize=(10, 7))
ax.plot(grid_search.param_grid['C'], grid_search.cv_results_['mean_test_score'])
ax.set(title='Зависимость CV-метрики от параметра регуляризации', xlabel='C', ylabel='AUC PR')
plt.show()

# %% [markdown]
# <div style="background: #f0f4e6; border: 2px solid #6b8e23;">
#     <p style="margin: 15px; line-height: 1.5; text-align: left;">
#         1) Получилось, что наиболее подходящий гиперпараметр C = 0.001 <br>
#         2) Взят маленькие промежуток перебора, так как иначе ничего не считается - с разрешения Ромы беру промежутки поменьше <br>
#         3) Выше показано, как классно можно перебрать - далее попробую перебором вручную

# %% [markdown]
#   На тестовой части:
#   - постройте ROC и PR кривые,
#   - посчитайте AUC-ROC, AUC-PR с точностью до 5 знаков

# %%
def plot_curves(model, X, y):
    y_proba = model.predict_proba(X)[:,1] # np.array([0.5] * X.shape[0])
    auc_pr, precision, recall = AUC_PR(y, y_proba, return_pr=True)
    fpr, tpr, thresholds = roc_curve(y, y_proba)
    auc_roc = auc(fpr, tpr)

    pr_edge = np.sum(y==1) / y.shape[0]
    metrics = {
        'AUC PR' : (auc_pr, recall, precision, {'x' : 'Recall', 'y' : 'Precision', 'random' : [[0,1], [1,pr_edge]]}),
        'AUC ROC'  : (auc_roc, fpr, tpr, {'x' : 'False Positive Rate', 'y' : 'True Positive Rate', 'random' : [[0,1], [0,1]]})
    }

    fig, ax = plt.subplots(1, 2, figsize=(25, 10))
    for i, m in enumerate(metrics.keys()):
        value, x, y, aux = metrics[m]
        value = np.round(value, 5)
        ax[i].plot(x, y, color='lightseagreen', lw=3, label=f"{m}={value}")
        x_r, y_r = aux['random']
        ax[i].plot(x_r, y_r, '--', color='lightgray', lw=2, label=f"{m.replace('AUC ', '')} curve (random classifier)")
        ax[i].set(title=m, xlabel=aux['x'], ylabel=aux['y'])
        
        ax[i].legend(loc='best', fontsize=14)

    plt.tight_layout()
    plt.show()

plot_curves(grid_search, X_test, y_test)

# %% [markdown]
# Сравните AUC-ROC и AUC-PR для вашей модели с этими же метриками для случайного классификатора.

# %%
# dataframe для сравнения 
# добавление очередной строки с характеристиками метода
svc = SVC(kernel='linear')
svc.fit(X_train,y_train)
y_pred_test = svc.predict(X_test)

df_metrics.loc['SVM Classifier'] = [
    auc(recall, precision),
    roc_auc_score(y_test, y_pred_test),
    None
]

# по аналогии результаты следующих экспериментов можно будет собрать в табличку
df_metrics
# Out:
#                      AUC_PR   AUC_ROC  reg_const
# Random Classifier  0.633402  0.503944        NaN
# SVM Classifier     0.633402  0.775138        NaN

# %% [markdown]
# <div style="background: #f0f4e6; border: 2px solid #6b8e23;">
#     <p style="margin: 15px; line-height: 1.5; text-align: left;">
#         Метод опорных векторов дал оценку AUC-ROC выше, чем случайный классификатор, что значит, что SVM сработал лучше, то есть увеличилась доля правильных классификаций таким способом<br>

# %% [markdown]
# __Logistic Regression__
#
# Теперь повторите то же самое для логистической регрессии (LR) — обучение, подбор параметра регуляризации (используйте L2-регуляризацию), вычисление метрик и построение кривых ROC и PR.

# %%
logreg = LogisticRegression(penalty='l2')
grid_search_2 = GridSearchCV(logreg, param_grid={'C' : [1e-04, 1e-03, 1e-02, 0.05, 0.1]}, scoring=auc_pr_score, n_jobs=-1)
grid_search_2.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.0001, 0.001, 0.01, 0.05, 0.1]},
#              scoring=make_scorer(AUC_PR, needs_proba=True))

# %%
fig, ax = plt.subplots(1, figsize=(10, 7))
ax.plot(grid_search_2.param_grid['C'], grid_search_2.cv_results_['mean_test_score'], color='lightsalmon')
ax.set(title='Зависимость CV-метрики от параметра регуляризации', xlabel='C', ylabel='AUC PR')
plt.show()

# %%
print('GridSearch CV best score : {:.4f}'.format(grid_search_2.best_score_))
print('Parameters that give the best results :', (grid_search_2.best_params_))
print('\nEstimator that was chosen by the search :', (grid_search_2.best_estimator_))
# Out:
# GridSearch CV best score : 0.8273
# Parameters that give the best results : {'C': 0.001}
#
# Estimator that was chosen by the search : LogisticRegression(C=0.001)

# %%
plot_curves(grid_search_2, X_test, y_test)

# %%
# dataframe для сравнения 
# добавление очередной строки с характеристиками метода
y_train_pred = grid_search_2.predict(X_test)


df_metrics.loc['LR'] = [
    auc(recall, precision),
    roc_auc_score(y_test, y_train_pred),
    None
]

# по аналогии результаты следующих экспериментов можно будет собрать в табличку
df_metrics
# Out:
#                      AUC_PR   AUC_ROC  reg_const
# Random Classifier  0.633402  0.503944        NaN
# SVM Classifier     0.633402  0.775138        NaN
# LR                 0.633402  0.767731        NaN

# %% [markdown]
# __Микровывод__
#
#   Сравните результаты LR и SVM с точки зрения всех вычисленных критериев качества, объясните различия (если они есть).
#
#   Ответ: # your answer here

# %% [markdown]
# <div style="background: #f0f4e6; border: 2px solid #6b8e23;">
#     <p style="margin: 15px; line-height: 1.5; text-align: left;">
#         В логистической регрессии с регуляризацией у нас лучше AUC-ROC, чем в случайном классификаторе, но хуже чем в SVM<br>
#         Точность в AUC-PR в начале (примерно 0.001 наверное) резко упала, зато потом поднялась и, начиная с 0.001, начала медленно снижаться<br>

# %% [markdown]
# #### __Задание 1.2. Визуализация в подходах SVM, LR__ (0.5 балла)
#
# В названии метода опорных векторов присутствуют некоторые "опорные векторы". По сути, это объекты из обучающей выборки, которые задали положение разделяющей гиперплоскости.
#
# 1) Сгенерируйте синтетические данные с помощью `make_classification` __с 2 признаками__, обучите на нём метод опорных векторов. В этот раз воспользуйтесь `SVC(kernel='linear')`, так как только в нём есть информация об опорных векторах, а в `LinearSVC` нет.
#
# 2) Визуализируйте разделяющую прямую, все объекты и выделите опорные векторы (атрибут `support_vectors_`).

# %%
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, random_state=22)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=22)

# %%
grid_search = GridSearchCV(estimator = SVC(kernel='linear'),  
                           param_grid = {'C':[1e-04, 1e-03, 1e-02, 0.05, 0.1]},
                           scoring = 'accuracy',
                           cv = 5)

grid_search.fit(X_train, y_train)

print('GridSearch CV best score : {:.4f}'.format(grid_search.best_score_))
print('Parameters that give the best results :', (grid_search.best_params_))
print('Estimator that was chosen by the search :', (grid_search.best_estimator_))
# Out:
# GridSearch CV best score : 0.9914
# Parameters that give the best results : {'C': 0.05}
# Estimator that was chosen by the search : SVC(C=0.05, kernel='linear')

# %%
# итого строим classifier
linear_svc = SVC(kernel='linear', C=0.1) 
linear_svc.fit(X_train, y_train)
y_pred_test = linear_svc.predict(X_test)

# считаем accuracy score
print('Model accuracy score with linear kernel and C=0.1 : {0:0.4f}'. format(accuracy_score(y_test, y_pred_test)))
# Out:
# Model accuracy score with linear kernel and C=0.1 : 0.9867

# %%
# V1
# визуализируем

import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

h = .02
svc = svm.SVC(kernel='linear', C=0.1).fit(X_train, y_train)

# create a mesh to plot in
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])

# result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)

# Plot also the training points
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.coolwarm)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title('SVC with linear kernel')

plt.show()

# %%
# V2 
#(https://scikit-learn.org/stable/auto_examples/svm/plot_linearsvc_support_vectors.html)
# получилось визуализировать через LinearSVC
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.svm import LinearSVC
from sklearn.inspection import DecisionBoundaryDisplay

plt.figure(figsize=(10, 5))
for i, C in enumerate([0.1, 100]):
    clf = LinearSVC(C=C, loss="hinge", random_state=22).fit(X_train, y_train)
    decision_function = clf.decision_function(X_train)
    support_vector_indices = np.where(np.abs(decision_function) <= 1 + 1e-15)[0]
    support_vectors = X_train[support_vector_indices]

    plt.subplot(1, 2, i + 1)
    plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, s=30, cmap=plt.cm.Paired)
    ax = plt.gca()
    DecisionBoundaryDisplay.from_estimator(
        clf,
        X_train,
        ax=ax,
        grid_resolution=50,
        plot_method="contour",
        colors="k",
        levels=[-1, 0, 1],
        alpha=0.5,
        linestyles=["--", "-", "--"],
    )
    plt.scatter(
        support_vectors[:, 0],
        support_vectors[:, 1],
        s=100,
        linewidth=1,
        facecolors="none",
        edgecolors="k",
    )
    plt.title("C=" + str(C))
plt.tight_layout()
plt.show()
# Out:
# /Users/isupport/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# В отличие от метода опорных векторов, логистическая регрессия не пытается построить разделяющую гиперплоскость с максимальным отступом, а приближает в каждой точке пространства объектов вероятность положительных ответов $p(y=+1|x)$. Попробуйте нарисовать это распределение на плоскости, не забудьте отметить на ней все объекты. Вам может помочь функция `plt.pcolor` ([matplotlib demo](https://matplotlib.org/3.1.1/gallery/images_contours_and_fields/pcolor_demo.html#sphx-glr-gallery-images-contours-and-fields-pcolor-demo-py)).

# %%
# LR


import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets

C = 0.1
h = .02
clf = LogisticRegression(C=C, penalty="l2", solver="saga", multi_class="multinomial", max_iter=10000)
clf.fit(X, y)

# create a mesh to plot in
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# result into a color plot
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)

# Plot also the training points
plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=plt.cm.coolwarm)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())
plt.title('L2 LR')

plt.show()

# %% [markdown]
# #### __Задание 2. Калибровка вероятностей__ (1 балл)
#
# Перейдём к оценке качества выдаваемых алгоритмами вероятностей. Начнём с калибровочных кривых.
#
# Допустим, алгоритм возвращает некоторые числа от нуля до единицы. Хорошо ли они оценивают вероятность? Для этого разобьем отрезок $[0, 1]$ на несколько маленьких отрезков одинаковой длины.
#
# Рассмотрим $i$-й отрезок с границами $[a_i, b_i]$ и предсказания $p_1, p_2, \dots, p_k$, которые попали в него. Пусть им соответствуют истинные ответы $y_1, y_2, \dots, y_k$. Если алгоритм выдает корректные вероятности, то среди этих истинных ответов должно быть примерно $(a_i + b_i) / 2$ единиц. Иными словами, если нарисовать кривую, у которой по оси X отложены центры отрезков, а по оси Y — доли единичных ответов этих в отрезках, то она должна оказаться диагональной.
#
# Ниже приведена функция, которая должна рисовать такие кривые. В ней допущено две ошибки — найдите и исправьте их.

# %%
from sklearn.calibration import calibration_curve
def plot_calibration_curve(y_test, preds):
    bin_middle_points = []
    bin_real_ratios = []
    n_bins = 10
    for i in range(n_bins):
        l = 1.0 / n_bins * i
        r = 1.0 / n_bins * (i + 1)
        bin_middle_points.append((l + r) / 2) # "-" -> "+"
        bin_real_ratios.append(np.mean(y_test[(preds >= l) & (preds < r)] == 1)) # min -> mean
    plt.figure(figsize=(6,6))
    plt.plot(bin_middle_points, bin_real_ratios)
    plt.ylim([-0.05, 1.05])
    plt.grid()

# %% [markdown]
# Сгенерируйте синтетические данные аналогично использованным в самом первом задании. Постройте калибровочные кривые на тестовой части для логистической регрессии и метода опорных векторов (не забудьте перевести его предсказания в $[0;1]$).

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, random_state=42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Изучите распределение ответов классификаторов (постройте гистограммы с помощью `plt.hist`).

# %%
svc = SVC(kernel='linear', probability=True).fit(X_train, y_train)
y_pred = svc.predict_proba(X_test)
x, y = calibration_curve(y_test, y_pred[:, 1], n_bins=20)

y_train_pred = svc.predict(X_test)
precision, recall, _ = precision_recall_curve(y_test, y_train_pred)
print('AUC-PR: %.5f' % auc(recall, precision)) #AUC-PR
print('AUC-ROC: %.5f' % roc_auc_score(y_test, y_train_pred)) #AUC-ROC

plt.xlabel('Mean predicted probability')
plt.ylabel('Count')
plt.hist(x, y)

plt.show()
# Out:
# AUC-PR: 0.87251
# AUC-ROC: 0.81998

# %%
clf = LogisticRegression(penalty="l2").fit(X_train, y_train)
y_pred = clf.predict_proba(X_test)
x, y = calibration_curve(y_test, y_pred[:, 1], n_bins=20)

y_train_pred = clf.predict(X_test)
precision, recall, _ = precision_recall_curve(y_test, y_train_pred)
print('AUC-PR: %.5f' % auc(recall, precision)) #AUC-PR
print('AUC-ROC: %.5f' % roc_auc_score(y_test, y_train_pred)) #AUC-ROC

plt.xlabel('Mean predicted probability')
plt.ylabel('Count')
plt.hist(x, y)

plt.show()
# Out:
# AUC-PR: 0.85197
# AUC-ROC: 0.78819

# %% [markdown]
# Чем они различаются? Чем вы можете объяснить это?

# %% [markdown]
# <div style="background: #f0f4e6; border: 2px solid #6b8e23;">
#     <p style="margin: 15px; line-height: 1.5; text-align: left;">
#         Распределение вероятностей с пропусками, в логистической регрессии заметно, что большее кол-во предсказано со средней вероятностью 0, обычно LR возвращает хорошо откалиброванные вероятности (https://scikit-learn.org/stable/modules/calibration.html#calibration) <br>
#         В нашем случае LR чуть лучше, так как мы видим высокие столбцы в диаграмме слева и справа, а относительно SVM - почти нет вероятностей около нуля <br>
#         При этом метрика упорядочивания объектов по классам (auc-roc) в LR хуже, а метрика класса и полноты (auc-pr, precision-recall) лучше

# %% [markdown]
# Воспользуйтесь `CalibratedClassifierCV` из `sklearn` для калибровки вероятностей метода опорных векторов на обучении и постройте с его помощью предсказания для тестовой выборки. Нарисуйте для них калибровочную кривую. Улучшилась ли она?

# %%
from sklearn.calibration import CalibratedClassifierCV
svc = SVC(kernel='linear', probability=True)
csvc = CalibratedClassifierCV(base_estimator=svc, cv=5).fit(X_train, y_train)
y_pred = csvc.predict_proba(X_test)
x, y = calibration_curve(y_test, y_pred[:, 1], n_bins=10)

plt.plot(y, x)
plt.show()

# %%
clf = LogisticRegression().fit(X_train, y_train)
cclf = CalibratedClassifierCV(base_estimator=clf, cv=5).fit(X_train, y_train)
y_pred = cclf.predict_proba(X_test)
x, y = calibration_curve(y_test, y_pred[:, 1], n_bins=10)

plt.plot(y, x)
plt.show()

# %% [markdown]
# <div style="background: #f0f4e6; border: 2px solid #6b8e23;">
#     <p style="margin: 15px; line-height: 1.5; text-align: left;">
#         Кривые, как и описано в теоретической части задания, диагональны (не идеально, но общая тенденция такая)

# %% [markdown]
# ##### __Бонус: Авторское решение__ (~0.5 балла~)
#
# Реализуйте свою функцию для калибровки вероятностей, используя любой из известных подходов. Кратко опишите ваш подход и продемонстрируйте результаты. Ключевые слова для вдохновения: `Platt`, `Isotonic`.

# %%
#your code here

# %% [markdown]
# # Часть 2. Обработка категориальных переменных (--4 балла--)

# %% [markdown]
# Как мы знаем, перекодировать категориальную переменную в список чисел (к примеру 1, 2, 3, ..., n) плохо, поскольку это бы задало на множестве ее значений некоторый порядок, не имеющий смысла.
#
# В этой части мы рассмотрим два основных способа обработки категориальных значений:
# - One-hot-кодирование
# - Счётчики (CTR, mean-target кодирование, ...) — каждый категориальный признак заменяется на среднее значение целевой переменной по всем объектам, имеющим одинаковое значение в этом признаке.
#
# Начнём с one-hot-кодирования. Допустим наш категориальный признак $f_j(x)$ принимает значения из множества $C=\{c_1, \dots, c_m\}$. Заменим его на $m$ бинарных признаков $b_1(x), \dots, b_m(x)$, каждый из которых является индикатором одного из возможных категориальных значений:
# $$
# b_i(x) = [f_j(x) = c_i]
# $$

# %% [markdown]
# #### __Подготовка данных__
#
# (бесценный шаг) 🤩
#
# Загрузим данные [UCI Adult Dataset](https://archive.ics.uci.edu/ml/datasets/Adult). Этот набор данных содержит информацию о годовых доходах отдельных людей. В качестве признакового описания используется различная информация о человеке (образование, профессия, брачный статус и т.д.). Целевая переменная является бинарной: больше ли годовой доход 50K долларов или нет.

# %%
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 
           'education-num', 'marital-status', 'occupation',
           'relationship', 'race', 'sex', 'capital-gain', 
           'capital-loss', 'hours-per-week', 'native-country',
           'income']

df = pd.read_csv('adult.data', header=None, names=columns)
df['income'] = (df['income'] != " <=50K").astype('int32')

# %%
df
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 24182   26            Private  104045      Bachelors             13
# 24183   49                  ?   57665      Bachelors             13
# 24184   38            Private  359001      Assoc-voc             11
# 24185   47            Private  105273      Bachelors             13
# 24186   31            Private  201122   Some-college             10
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# Разделите выборку на обучающую и тестовую в соотношении 3:1. Зафиксируйте `random_state=777`, также используйте `stratify`.

# %%
df['race'] = df['race'].fillna('unknown')
df['sex'] = df['sex'].fillna('unknown')
df['native-country'] = df['native-country'].fillna('unknown')
df['capital-gain'] = df['capital-gain'].fillna(0)
df['capital-loss'] = df['capital-loss'].fillna(0)
df['hours-per-week'] = df['hours-per-week'].fillna(0)
df = df.rename(columns = {'income': 'y'})

# %%
X = df.copy().drop(columns = 'y')
y = df['y']

X_train, X_test, y_train, y_test = train_test_split(X, y,  test_size=0.25, random_state=777, stratify = y)

# %% [markdown]
# #### __Задание 3. OrdinalEncoder__  (0.5 балла)
#
# Закодируйте категориальные признаки с помощью `OrdinalEncoder`, а числовые признаки нормализуйте с помощью `StandardScaler`. Посчитайте качество (в этом задании будем работать c __`AUC-PR`__) при применении логистической регрессии. Замерьте время, потребовавшееся на обучение модели, с учетом кодирования признаков.

# %%
column_transformer = ColumnTransformer([
    ('ordinal', OrdinalEncoder(), (X_train.dtypes)[X_train.dtypes == object].index.tolist()),
    ('scaling', StandardScaler(), ['age', 'capital-gain', 'hours-per-week', 'capital-loss']),
    ('other',  'passthrough', (X_train.dtypes)[X_train.dtypes != object].index.tolist()[1:])
])

# %% [markdown]
# __Вопрос__: почему в данном задании мы выбрали метрикой именно `AUC-PR`, а не, к примеру, `AUC-ROC`?
#
# __Ответ__: # your answer here

# %% [markdown]
# #### __Задание 4. One-Hot Encoding__ (0.5 балла)

# %% [markdown]
# Закодируйте все категориальные признаки с помощью one-hot-кодирования. Обучите логистическую регрессию и посмотрите, как изменилось качество модели (в сравнении с тем, что было до кодирования). Измерьте время, потребовавшееся на кодирование категориальных признаков и обучение модели.

# %%
time_start = time.time()

X_train_1 = column_transformer.fit_transform(X_train)
X_test_1 = column_transformer.transform(X_test)

lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_1, y_train)

ordinal_encoder_time = time.time() - time_start
ordinal_encoder_auc = AUC_PR(y_test, lr.predict_proba(X_test_1)[:,1])

# %%
def print_results(t, auc):
    t = np.round(t, 3)
    auc = np.round(auc, 3)
    print(f"Time: {t}s,\nAUC PR: {auc}")

# %%
print_results(ordinal_encoder_time, ordinal_encoder_auc)
# Out:
# Time: 0.27s,
# AUC PR: 0.514

# %% [markdown]
# Как можно заметить, one-hot-кодирование может сильно увеличивать количество признаков. Это сказывается на объеме необходимой памяти, особенно, если некоторый признак имеет большое количество значений.

# %% [markdown]
# #### __Задание 5. Mean-target Encoding__ (1 балл)

# %% [markdown]
# > Проблемы разрастания числа признаков можно избежать в другом способе кодирования категориальных признаков — mean-target encoding (для простоты будем называть это __счётчиками__). Сравним эффективность методов в рамках нашей маркетинговой задачи.
#
# > Основная идея в том, что важны не сами категории, а значения целевой переменной, которые имеют объекты этой категории. Каждый категориальный признак мы заменим средним значением целевой переменной по всем объектам этой же категории:
# $$
# g_j(x, X) = \frac{\sum_{i=1}^{\ell} [f_j(x) = f_j(x_i)][y_i = +1]}{\sum_{i=1}^{\ell} [f_j(x) = f_j(x_i)]}
# $$
#
# Закодируйте категориальные переменные с помощью счётчиков (ровно так, как описано выше, без каких-либо хитростей). Обучите логистическую регрессию и посмотрите на качество модели на тестовом множестве.
#
# Сравните время обучения с предыдущими экспериментами (с учетом кодирования признаков).

# %%
column_transformer = ColumnTransformer([
    ('ordinal', OneHotEncoder(), (X_train.dtypes)[X_train.dtypes == object].index.tolist()),
    ('scaling', StandardScaler(), ['age']),
    ('other',  'passthrough', (X_train.dtypes)[X_train.dtypes != object].index.tolist()[1:])
])

# %%
time_start = time.time()

X_train_2 = column_transformer.fit_transform(X_train)
X_test_2 = column_transformer.transform(X_test)

lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_2, y_train)

onehot_encoder_time = time.time() - time_start
onehot_encoder_auc = AUC_PR(y_test, lr.predict_proba(X_test_2)[:,1])

# %%
print_results(onehot_encoder_time, onehot_encoder_auc)
# Out:
# Time: 0.318s,
# AUC PR: 0.461

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from collections import defaultdict

class MeanTargetEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, columns, random=False):
        self.columns = columns
        self.random = random


    def fit(self, X, y):
        Xf = X.copy()
        Xf['y'] = y
        self.maps = defaultdict(dict)

        for col in self.columns:
            self.maps[col] = Xf.groupby(col)['y'].mean().to_dict()


    def transform(self, X, y=None):
        Xt = X.copy()
        for col in self.columns:
            Xt[col] = Xt[col].apply(lambda x: self.maps[col].get(x, 0))
            if self.random:
                Xt[col] += np.random.normal(0, 10, Xt.shape[0])

        return Xt

    
    def fit_transform(self, X, y):
        self.fit(X, y=y)
        return self.transform(X)

# %%
time_start = time.time()

encoder = MeanTargetEncoder((X_train.dtypes)[X_train.dtypes == object].index.tolist())
X_train_3 = encoder.fit_transform(X_train, y_train)
X_test_3 = encoder.transform(X_test, y_train)

X_train_3['age'] = (X_train_3['age'] - X_train_3['age'].mean()) / np.std(X_train_3['age'])
X_test_3['age'] = (X_test_3['age'] - X_test_3['age'].mean()) / np.std(X_test_3['age'])

lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_3, y_train)

meantarg_encoder_time = time.time() - time_start
meantarg_encoder_auc = AUC_PR(y_test, lr.predict_proba(X_test_3)[:,1])

# %%
print_results(meantarg_encoder_time, meantarg_encoder_auc)
# Out:
# Time: 0.306s,
# AUC PR: 0.461

# %% [markdown]
# ##### __Бонус: Эффективная реализация (1 балл)__
#
# Здесь и далее реализуйте вычисление счетчиков с помощью трансформера (наследуйтесь от классов `BaseEstimator, TransformerMixin` из `sklearn.base`). Обратите внимание, что все вычисления должны быть векторизованными, трансформер не должен модифицировать передаваемую ему выборку inplace, а все необходимые статистики нужно считать только по обучающей выборке в методе `fit`. Ваш трансформер должен принимать при инициализации список из категориальных признаков и изменять только их.

# %% [markdown]
# _______
#
# __Методы борьбы с переобучением счетчиков__
#
#
# Отметим, что mean-target encoding признаки сами по себе являются классификаторами и, обучаясь на них, мы допускаем "утечку" целевой переменной в признаки. Это ведёт к __переобучению__, поэтому считать такие признаки необходимо таким образом, чтобы при вычислении для конкретного объекта его __целевая метка не использовалась__.
#
# Это можно делать следующими способами:
# 1. Вычислять значение счётчика по всем объектам расположенным выше в датасете (например, если у нас выборка отсортирована по времени).
# 2. Вычислять по фолдам, то есть делить выборку на некоторое количество частей и подсчитывать значение признаков по всем фолдам кроме текущего (как делается в кросс-валидации).
# 3. Внесение некоторого шума в посчитанные признаки.
#
# #### __Задание 6. Пошумим__  (0.5 балла)
#
# Реализуйте корректное вычисление счётчиков самым простым способом — добавление шума к значениям.  При этом постарайтесь найти баланс между борьбой с переобучением и сохранением полезности признаков. Снова обучите логистическую регрессию, оцените качество. Сделайте выводы.

# %%
time_start = time.time()

encoder = MeanTargetEncoder((X_train.dtypes)[X_train.dtypes == object].index.tolist(), random=True)
X_train_4 = encoder.fit_transform(X_train, y_train)
X_test_4 = encoder.transform(X_test, y_train)

X_train_4['age'] = (X_train_4['age'] - X_train_4['age'].mean()) / np.std(X_train_4['age'])
X_test_4['age'] = (X_test_4['age'] - X_test_4['age'].mean()) / np.std(X_test_4['age'])

lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_4, y_train)

meantarg_rand_encoder_time = time.time() - time_start
meantarg_rand_encoder_auc = AUC_PR(y_test, lr.predict_proba(X_test_4)[:,1])

# %%
print_results(meantarg_rand_encoder_time, meantarg_rand_encoder_auc)
# Out:
# Time: 0.33s,
# AUC PR: 0.46

# %% [markdown]
# ##### __Бонус: другой подход__ (0.5 балла)
#
# Посчитайте корректные счётчики первым или вторым способов из описанных выше (не забудьте добавить и шум).

# %%
#your code here

# %% [markdown]
# #### __Задание 7. Сглаживание счетчиков__  (1 балл)

# %% [markdown]
# > Теперь ответим на следующий вопрос: что будет, если некоторая категория встречается в выборке всего несколько раз? По этой причине производится сглаживание счётчиков. Например, на практике хорошие результаты показывает использование сглаживания средним по всей выборке:
# $$
# g_j(x, X) = \frac{\sum_{i=1}^{\ell} [f_j(x) = f_j(x_i)][y_i = +1] + C \times global\_mean}{\sum_{i=1}^{\ell} [f_j(x) = f_j(x_i)] + C}
# $$
# где $global\_mean$ — доля объектов положительного класса в выборке, $C$ — параметр, определяющий степень сглаживания (можно использовать 10 или подобрать для каждого признака свой). Идея в том, что мы "разбавляем" среднее значение по категории глобальным средним значением. И тем меньше, чем большее количество объектов этой категории встречается в выборке.
#
# > Вместо среднего значения целевой переменной для сглаживания можно использовать любое другое значение от 0 до 1 (этот параметр иногда называют $prior$). Можно сделать несколько признаков с разными значениями параметра. На практике в задачах бинарной классификации полезными бывают даже отрицательные значения!
#
# Добавьте сглаживание, описанное выше и повторите эксперименты.

# %%
class MeanTargetSmoothEncoder(BaseEstimator, TransformerMixin):
    def __init__(self, columns, C=0):
        self.columns = columns
        self.C = C


    def fit(self, X, y):
        Xf = X.copy()
        Xf['y'] = y
        self.maps = defaultdict(dict)

        for col in self.columns:
            encoding = (Xf.groupby(col)['y'].sum() + self.C * np.mean(y)) / (Xf.groupby(col)['y'].count() + self.C)
            self.maps[col] = encoding.to_dict()


    def transform(self, X, y=None):
        Xt = X.copy()
        for col in self.columns:
            Xt[col] = Xt[col].apply(lambda x: self.maps[col].get(x, 0))

        return Xt

    
    def fit_transform(self, X, y):
        self.fit(X, y=y)
        return self.transform(X)

# %%
time_start = time.time()

encoder = MeanTargetSmoothEncoder((X_train.dtypes)[X_train.dtypes == object].index.tolist(), C=10)
X_train_5 = encoder.fit_transform(X_train, y_train)
X_test_5 = encoder.transform(X_test, y_train)

X_train_5['age'] = (X_train_5['age'] - X_train_5['age'].mean()) / np.std(X_train_5['age'])
X_test_5['age'] = (X_test_5['age'] - X_test_5['age'].mean()) / np.std(X_test_5['age'])

lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_5, y_train)

meansmoothtarg_rand_encoder_time = time.time() - time_start
meansmoothtarg_rand_encoder_auc = AUC_PR(y_test, lr.predict_proba(X_test_5)[:,1])

# %%
print_results(meansmoothtarg_rand_encoder_time, meansmoothtarg_rand_encoder_auc)
# Out:
# Time: 0.453s,
# AUC PR: 0.461

# %% [markdown]
# #### __Задание 8. И все-таки числовой?__  (0.5 балла)
#
# В данных имеются признаки "возраст" и "число рабочих часов в неделю". Сейчас мы интерпретируем их как числовые, что в общем случае для линейной модели может быть неверной гипотезой. Тем не менее, у этих признаков есть довольно много уникальных значений (сколько?), поэтому применять к ним one-hot кодирование может оказаться излишним. Попробуйте закодировать эти признаки с помощью счетчиков (вместе и по отдельности). Стало ли лучше?

# %%
time_start = time.time()

encoder = MeanTargetEncoder((X_train.dtypes)[X_train.dtypes == object].index.tolist() + ['age', 'hours-per-week'], random=False)
X_train_6 = encoder.fit_transform(X_train, y_train)
X_test_6 = encoder.transform(X_test, y_train)

lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_6, y_train)

meantarg_age_encoder_time = time.time() - time_start
meantarg_age_encoder_auc = AUC_PR(y_test, lr.predict_proba(X_test_6)[:,1])

# %%
print_results(meantarg_age_encoder_time, meantarg_age_encoder_auc)
# Out:
# Time: 0.276s,
# AUC PR: 0.477

# %% [markdown]
# > __Замечание.__ Усложнение методов вычисления счётчиков не делают результаты модели гарантированно лучше. Особенно с учётом того, что логистическая регрессия не такая сложная модель, чтобы переобучаться. Поэтому вы необязательно должны были получать на каждом шаге всё лучшие и лучшие результаты (но необходимые результаты у вас должны были получиться).
#
# Как мы могли пронаблюдать, счётчики являются конкурентной альтернативой one-hot-кодированию. Опишите, какие плюсы и минусы использования счётчиков по сравнению с one-hot-кодированием вы заметили.
#
# __Ответ:__ # your answer here

# %% [markdown]
# # Часть 3. Отбор признаков

# %% [markdown]
# Важной частью процесса построения модели является отбор признаков. На практике многие признаки оказывают малое влияние на модель (при этом их расчёт занимает время) или даже негативно сказываются на качестве модели. Попробуем несколько подходов отбора признаков, оценим, как они влияют на качество модели и сколько времени занимают.
#
# Обратимся к тем же данным про предсказание дохода.

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 
           'education-num', 'marital-status', 'occupation',
           'relationship', 'race', 'sex', 'capital-gain', 
           'capital-loss', 'hours-per-week', 'native-country',
           'income']

df = pd.read_csv('adult.data', header=None, names=columns)
df['income'] = (df['income'] != " <=50K").astype('int32')

# %% [markdown]
# Разделите выборку на обучающую и тестовую в соотношении 3:1. Зафиксируйте `random_state=777`, также используйте `stratify`.

# %%
df['race'] = df['race'].fillna('unknown')
df['sex'] = df['sex'].fillna('unknown')
df['native-country'] = df['native-country'].fillna('unknown')
df['capital-gain'] = df['capital-gain'].fillna(0)
df['capital-loss'] = df['capital-loss'].fillna(0)
df['hours-per-week'] = df['hours-per-week'].fillna(0)
df = df.rename(columns = {'income': 'y'})

X = df.drop(columns='y')
y = df['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777, stratify=y)

# %% [markdown]
# Давайте закодируем все категориальные признаки с помощью One-hot Encoding, считая возраст и число часов числовыми. Сколько новых признаков мы получим?

# %%
categoricals = (X_train.dtypes)[X_train.dtypes == object].index.tolist()
numeric = (X_train.dtypes)[X_train.dtypes != object].index.tolist()

column_transformer = ColumnTransformer([
    ('ordinal', OneHotEncoder(), categoricals),
    ('other',  'passthrough', numeric)
])

X_train_oh = column_transformer.fit_transform(X_train)
X_test_oh = column_transformer.transform(X_test)

print(f"Число признаков после One-hot кодирования: {X_test_oh.shape[1]}")
# Out:
# Число признаков после One-hot кодирования: 112

# %% [markdown]
# В качестве основной модели будем использовать логистическую регрессию, а целевой метрики — `AUC-PR`. Обучите модель и посчитайте качество на тестовой выборке. Давайте запомним полученное значение.

# %%
def print_results(t, auc):
    t = np.round(t, 3)
    auc = np.round(auc, 3)
    print(f"Time for feature selection: {t}s,\nAUC PR: {auc}")

lr_base = LogisticRegression(max_iter=10000)
lr_base.fit(X_train_oh, y_train)

base_auc_pr = AUC_PR(y_test, lr_base.predict_proba(X_test_oh)[:,1])

print_results(0, base_auc_pr)
# Out:
# Time for feature selection: 0s,
# AUC PR: 0.457

# %% [markdown]
# #### __Задание 9. Встроенные методы (0.5 балла)__

# %% [markdown]
# Допустим, мы хотим оставить только 40 лучших признаков. Попробуем сделать это несколькими способами.
#
# Начнём с отборам признаков с помощью линейной модели. Как известно, веса линейной модели означают вклад каждого признака в предсказание модели, а значит, модуль этого вклада можно интерпретировать как важность признаков. Такой метод отбора называются встроенным или embedded method, так как он заложен в особенности модели.
#
# Оставьте 40 признаков с наибольшим модулем соответствующего параметра линейной модели. Обучите модели заново и оцените её качество. Замерьте скорость такого отбора признаков.

# %%
time_start = time.time()

features_to_keep = (lr_base.coef_ > np.quantile(lr_base.coef_, (112-40)/112))[0]
X_train_1 = X_train_oh[:,features_to_keep]
X_test_1 = X_test_oh[:,features_to_keep]

time_embedded = time.time() - time_start

# %%
lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_1, y_train)

embedded_auc_pr = AUC_PR(y_test, lr.predict_proba(X_test_1)[:,1])

# %%
print_results(time_embedded, embedded_auc_pr)
# Out:
# Time for feature selection: 0.006s,
# AUC PR: 0.742

# %% [markdown]
# Изменилось ли качество? Как?

# %% [markdown]
# Подумаем, что мы не учли. Мы действовали в предположении, что признаки вносят вклад равномерно, и не учитывали их масштаб. Если мы умножим один из признаков в 100 раз, то без учёта регуляризации его вес уменьшится в эти же 100 раз. А мы на основе этого отбираем признаки! Давайте сначала отмасштабируем признаки одним из способов, а только потом будем удалять признаки.
#
# Кстати, в таком случае надо пересчитать качество на всех признаках (сделайте это ниже). Если вы сделали нормирование признаков в самом начале, то попробуйте отобрать признаки на неотмасштабированных данных.
#
# Что получилось?

# %%
column_transformer = ColumnTransformer([
    ('ordinal', OneHotEncoder(), (X_train.dtypes)[X_train.dtypes == object].index.tolist()),
    ('scaling', StandardScaler(), (X_train.dtypes)[X_train.dtypes != object].index.tolist()[0:]),
])

X_train_oh = column_transformer.fit_transform(X_train)
X_test_oh = column_transformer.transform(X_test)

lr_base_2 = LogisticRegression(max_iter=10000)
lr_base_2.fit(X_train_oh, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
time_start = time.time()

features_to_keep = (lr_base_2.coef_ > np.quantile(lr_base_2.coef_, (62-40)/62))[0]
X_train_2 = X_train_oh[:,features_to_keep]
X_test_2 = X_test_oh[:,features_to_keep]

time_embedded = time.time() - time_start


lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_2, y_train)

embedded_auc_pr = AUC_PR(y_test, lr.predict_proba(X_test_2)[:,1])
print_results(time_embedded, embedded_auc_pr)
# Out:
# Time for feature selection: 0.007s,
# AUC PR: 0.77

# %% [markdown]
# Вопрос на засыпку: one-hot кодирование возвращает нам единичные признаки-индикаторы. Попробуйте также отскалировать их, как и обычные числовые, и снова выбрать 40 главных по вкладу признаков. Изменился ли их список? Изменится ли качество?

# %% [markdown]
# #### __Задание 10. Методы фильтрации (0.5 балла)__
#
#
# Давайте отбирать признаки умнее, а именно через подсчёт некоторой функции для каждого признака. На основании значений этой функции будем оставлять наиболее важные признаки. Методы этого семейства называют фильтрующими или  filter methods.
#
# В качестве такой функции будем считать t-статистику:
#
# $$t(j) = \frac{|\mu_+ - \mu_-|}{\sqrt{\frac{n_+ \sigma^2_+ + n_- \sigma^2_-}{n_+ + n_-}}},$$
#
# где $\mu$, $\sigma$, $n$ соответственно среднее, стандартное отклонение и количество объектов каждого из классов.
#
# Оставьте 40 признаков с наибольшим значением $t$, замерьте качество и скорость отбора признаков.

# %%
column_transformer = ColumnTransformer([
    ('ordinal', OneHotEncoder(), (X_train.dtypes)[X_train.dtypes == object].index.tolist()),
    ('scaling', StandardScaler(), (X_train.dtypes)[X_train.dtypes != object].index.tolist()[0:]),
])

X_train_oh = column_transformer.fit_transform(X_train)
X_test_oh = column_transformer.transform(X_test)

# %%
y_train = np.int8(y_train.values.flatten() == 'yes')
y_test = np.int8(y_test.values.flatten() == 'yes')
# Out:
# <ipython-input-250-b2c0fff32f97>:1: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y_train = np.int8(y_train.values.flatten() == 'yes')
# <ipython-input-250-b2c0fff32f97>:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   y_test = np.int8(y_test.values.flatten() == 'yes')

# %%
time_start = time.time()

feat_sel = []

for i in range(X_train_oh.shape[1]):
    idx_yes = (y_train == 1)
    idx_no = (y_train != 1)

    feat = X_train_oh[:,i]

    yes = feat[idx_yes]
    no = feat[idx_no]
    

    n_yes = yes.shape[0]
    n_no = no.shape[0]

    mean_yes = np.mean(yes)
    mean_no = np.mean(no)

    var_yes = np.var(yes)
    var_no = np.var(no)

    t = np.abs(mean_yes-mean_no) / np.sqrt((n_yes*var_yes + n_no*var_no) / (n_yes+n_no))

    feat_sel.append([i, t])
# Out:
# /Users/isupport/opt/anaconda3/lib/python3.8/site-packages/scipy/sparse/base.py:581: RuntimeWarning: divide by zero encountered in true_divide
#   return self.astype(np.float_)._mul_scalar(1./other)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'csr_matrix'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-67187259c0dc> in <module>
#      19     mean_no = np.mean(no)
#      20
# ---> 21     var_yes = np.var(yes)
#      22     var_no = np.var(no)
#      23
#
# <__array_function__ internals> in var(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in var(a, axis, dtype, out, ddof, keepdims, where)
# ...

# %%
keep = sorted(feat_sel, key=lambda x: -x[1])[:40]
keep = [i[0] for i in keep]

X_train_3 = X_train_oh[:,keep]
X_test_3 = X_test_oh[:,keep]

time_filter = time.time() - time_start


lr = LogisticRegression(max_iter=10000)
lr.fit(X_train_3, y_train)

filter_auc_pr = AUC_PR(y_test, lr.predict_proba(X_test_3)[:,1])
print_results(time_filter, filter_auc_pr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-245-1daed0cf6d4d> in <module>
#       9
#      10 lr = LogisticRegression(max_iter=10000)
# ---> 11 lr.fit(X_train_3, y_train)
#      12
#      13 filter_auc_pr = AUC_PR(y_test, lr.predict_proba(X_test_3)[:,1])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1136             _dtype = [np.float64, np.float32]
#    1137
# -> 1138         X, y = self._validate_data(
#    1139             X,
#    1140             y,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
# ...

# %% [markdown]
# #### __Задание 11. Методы-обёртки__ (1 балл)
#
# Третий из рассматриваемых нами методов работает следующим образом: мы исключаем по очереди один из признаков и смотрим, как это влияет на качество. Удаляем признаки таким жадным способом, пока не окажется выполненым некоторое условие (количество признаков или ухудшение качества). Более конкретно, на каждом шаге мы будем удалять такой признак $j$, что качество модели на множестве оставшихся признаков без $j$ максимально, то есть удалять мы будем наиболее бесполезный признак.
#
# Заметим, что нельзя оценивать качество по тестовой выборке, иначе мы можем переобучиться, как, например, при настройке гиперпараметров. Разделите обучающую выборку на 2 части, на одной из них обучайте модель без одного из признаков,  на второй части оценивайте качество. Исходную тестовую выборку стоит использовать только для финальной оценки качества.
#
# Снова оставьте только 40 признаков и оцените качество на тестовой выборке. Сколько времени занял такой отбор признаков?

# %%
#your code here

# %% [markdown]
# Стоит отметить, что с помощью такого метода можно пойти и в обратную сторону. Попробуйте _добавлять_ по одному самому полезному признаку в выборку до тех пор, пока не наберется 40 штук. Найдется ли порог, при котором добавление следующих признаков будет только ухудшать качество модели?

# %%
#your code here

# %% [markdown]
# Давайте подведём итоги по отбору признаков. Назовите преимущества и недостатки каждого из методов. Какой метод привёл к наилучшему качеству?
#
# **Ответ:**

# %% [markdown]
# # Часть 4. Оценка экономического эффекта модели
#
# > В данной части мы займемся тем, что от вас скорее всего потребуется на реальной работе (помимо перекладки `json`, разумеется). А именно:
# - мы соберем несколько специализированных метрик качества,
# - попытаемся настроить модель на максимизацию _прибыли_,
# - оценим, сколько вообще получится заработать на этом.
#
# > Разумеется, здесь будет сделано множество упрощающих жизнь допущений, но обо всем по порядку. Если вы всё прослушали на экономике, то напомним, что выручка — это сколько денег нам принесли клиенты, а прибыль — выручка за вычетом расходов на зарплату и прочее.

# %% [markdown]
# #### __Задание 12. Прогноз по доходам и расходам__ (1 балл)
#
# В этой части мы будем работать с данными [UCI Bank Marketing Dataset](https://archive.ics.uci.edu/ml/datasets/bank+marketing). Этот датасет содержит информацию о банковском телефонном маркетинге.
#
# __Объектом__ здесь является телефонный звонок потенциальному клиенту с предложением некоторой услуги (утверждается, что это краткосрочный депозит). В качестве признакового описания используются характеристики клиента (образование, брак и т.д.), данные о звонке и различные экономические индикаторы - более подробная информация представлена в файле `bank-additional-names.txt`.
# __Целевая переменная__ - ответ клиента (согласился ли он открыть депозит?)

# %%
#!wget https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
#!unzip bank-additional.zip
df = pd.read_csv('bank-additional/bank-additional-full.csv', sep=';')
# Out:
# --2022-11-27 12:50:48--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu... 128.195.10.252
# Connecting to archive.ics.uci.edu|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444572 (434K) [application/x-httpd-php]
# Saving to: 'bank-additional.zip.1'
#
# bank-additional.zip 100%[===================>] 434.15K   367KB/s    in 1.2s
#
# 2022-11-27 12:50:50 (367 KB/s) - 'bank-additional.zip.1' saved [444572/444572]
#
# Archive:  bank-additional.zip
# replace bank-additional/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %% [markdown]
# В этой части не нужно делить выборку - мы будем использовать кросс-валидацию.  Используйте 5 фолдов, сделайте `shuffle=True, random_state=500`. По кросс-валидации у вас получится 5 вариантов обучающей и тестовой выборки.

# %%
from sklearn.model_selection import KFold

df = pd.read_csv('bank-additional/bank-additional-full.csv', sep=';')

X = df.drop(columns=['duration', 'y'])
y = (df.y == 'yes')

column_transformer = ColumnTransformer([
    ('ordinal', OneHotEncoder(), (X.dtypes)[X.dtypes == object].index.tolist()),
    ('scaling', StandardScaler(), ['age']),
    ('other',  'passthrough', (X.dtypes)[X.dtypes != object].index.tolist()[1:])
])

X = column_transformer.fit_transform(X)

kf = KFold(n_splits=5, shuffle=True, random_state=500)

# %%
cv_revenues = []
cv_costs = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = LogisticRegression(max_iter=10000)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    revenue = 10*(preds & y_test).sum() # мы получим деньги, если мы позвонили и клиент согласился
    cost = np.sum(preds) # а заплатим мы в любом случае
    cv_revenues.append(revenue)
    cv_costs.append(cost)

mean_revenue = np.round(np.mean(cv_revenues))
std_revenue = np.round(np.std(cv_revenues))
mean_cost = np.round(np.mean(cv_costs))

# %%
print(f"Mean revenue: {mean_revenue}\nStandard deviation: {std_revenue}\n\nMean cost: {mean_cost}")
# Out:
# Mean revenue: 2094.0
# Standard deviation: 58.0
#
# Mean cost: 311.0

# %% [markdown]
# Обучите логистическую регрессию на каждой обучающей выборке (воспользуйтесь one-hot для категориальных признаков и `StandardScaler` для числовых, гиперпараметры по умолчанию) и сделайте предсказания для соответствующих тестовых выборок.

# %% [markdown]
# Допустим, работники вашего колл-центра получают за один звонок клиенту 1 доллар. При согласии клиента на предлагаемые условия он принесет в банк 10 долларов. Предположим, что всем положительным прогнозам ваши сотрудники решили позвонить. Посчитайте на всех тестовых выборках выручку и усредните. Также вычислите стандартное отклонение.
# - Сколько денег вы в среднем заработаете?
# - Сколько из заработанных денег придётся отдать операторам вашего колл-центра?

# %%
# your code here

# %% [markdown]
# Внесем некоторую долю случайности. Пусть теперь согласный на условия клиент будет приносить не 10 долларов, а случайную величину, равномерно распределенную в интервале $[0;20)$. Проделайте все те же самые действия. Для имитации реальной ситуации **НЕ** фиксируйте `random_seed` при подсчете выручки с клиента. Что получилось?

# %%
cv_revenues = []
cv_costs = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = LogisticRegression(max_iter=10000)
    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    revenue = (preds & y_test) * np.random.uniform(0, 20, y_test.shape[0])
    revenue = revenue.sum()

    cost = np.sum(preds)
    cv_revenues.append(revenue)
    cv_costs.append(cost)

mean_revenue = np.round(np.mean(cv_revenues))
std_revenue = np.round(np.std(cv_revenues))
mean_cost = np.round(np.mean(cv_costs))

# %%
print(f"Mean revenue: {mean_revenue}\nStandard deviation: {std_revenue}\n\nMean cost: {mean_cost}")
# Out:
# Mean revenue: 2029.0
# Standard deviation: 49.0
#
# Mean cost: 311.0

# %% [markdown]
# Настройте по кросс-валидации коэффициент регуляризации модели для максимизации прибыли (считайте как случайную величину выше). Удалось ли получить какой-то выигрыш? При каком коэффициенте регуляризациии прибыль максимальна? Постройте график зависимости ожидаемой прибыли от коэффициента, укажите стандартные отклонения (вам поможет `plt.errorbar`, [пример](https://jakevdp.github.io/PythonDataScienceHandbook/04.03-errorbars.html)).

# %%
C = [0.01, 0.05, 0.1, 0.5, 10, 100, 1000]
history = []

for reg in C:
    cv_profits = []

    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        model = LogisticRegression(max_iter=10000, C=reg)
        model.fit(X_train, y_train)
        preds = model.predict(X_test)

        revenue = (preds & y_test) * np.random.uniform(0, 20, y_test.shape[0])
        revenue = revenue.sum()
        cost = np.sum(preds)
        profit = revenue - cost

        cv_profits.append(profit)

    mean_profit = np.round(np.mean(cv_profits))
    std_profit = np.round(np.std(cv_profits))

    history.append([reg, mean_profit, std_profit])

history = pd.DataFrame(history, columns=['C', 'mean_profit', 'std_profit'])

# %%
fig, ax = plt.subplots(1, figsize=(7, 4))
ax.bar(history.C.astype(str), history.mean_profit, yerr=history.std_profit, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set(title='Ожидаемая прибыль и регуляризация', xlabel='C (гиперпараметр)', ylabel='Прибыль')
plt.show()

# %% [markdown]
# Попробуйте запустить перебор несколько раз. Находится ли каждый раз один и тот же "лучший" коэффициент? Присутствует ли какая-то закономерность? Какие вы можете сделать из этого выводы?

# %%
#your code here

# %% [markdown]
# #### __Задание 13. Ключевая метрика__ (1 балл)
#
# Выше мы уже описали примерную экономическую модель вашей задачи. Как вы считаете, что для вашего бизнеса важнее — хороший precision или recall модели? Почему?
#
# __Ответ:__ # your answer here

# %% [markdown]
# > Вспомним, что на самом деле логистическая регрессия предсказывает нам вероятности положительного класса для объекта. Возможно, путем настройки __порога бинаризации__ этих вероятностей мы сможем получить какой-то выигрыш?
#
# Проверьте ваши рассуждения выше с помощью настройки порога бинаризации на кросс-валидации для максимизации прибыли. Воспользуйтесь сеткой от 0 до 1 с шагом 0.01. Напомним, что снижение порога дает нам более высокий recall и более низкий precision, и наоборот.

# %%
grid = np.arange(0, 1, 0.01)
history = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = LogisticRegression(max_iter=10000)
    model.fit(X_train, y_train)
    gains = np.random.uniform(0, 20, y_test.shape[0])

    for threshold in grid:
        preds = model.predict_proba(X_test)[:,1]
        preds = preds > threshold
        revenue = (preds & y_test) * gains
        revenue = revenue.sum()
        cost = np.sum(preds)
        profit = revenue - cost

        history.append([threshold, profit])


history = pd.DataFrame(history, columns=['threshold', 'profit'])
history = history.groupby('threshold').agg({'profit' : 'mean'}).join(history.groupby('threshold').agg({'profit' : 'std'}).rename(columns={'profit':'std'}))
history = history.reset_index()

# %%
fig, ax = plt.subplots(1, figsize=(7, 4))
ax.errorbar(history.threshold, history.profit, yerr=history['std'], color='darkgray')
best = history.sort_values('profit').tail(1).values[0]
ax.plot(best[0], best[1], 'o', color='red')
ax.set(title='Ожидаемая прибыль и вероятностный порог', xlabel='Threshold', ylabel='Прибыль')
plt.show()

# %% [markdown]
# Постройте график зависимости прибыли от порога бинаризации, также отметьте на нем стандартные отклонения. Выделите наилучший порог.
#
#
# __Вопрос:__ Замечаете ли вы какую-то закономерность? Для правильного ответа на этот вопрос попробуйте запустить несколько раз и задумайтесь, почему порог получается в какой-то конкретной области?

# %%
#your code here

# %% [markdown]
# Каковы значения precision и recall на выбранном пороге? Оцените по кросс-валидации. Также вычислите стандартное отклонение.

# %%
pr = []
rec = []

for train_index, test_index in kf.split(X):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

    model = LogisticRegression(max_iter=10000)
    model.fit(X_train, y_train)
    gains = np.random.uniform(0, 20, y_test.shape[0])

    threshold = best[0]
    preds = model.predict_proba(X_test)[:,1]
    preds = preds > threshold
    revenue = (preds & y_test) * gains
    revenue = revenue.sum()
    cost = np.sum(preds)
    profit = revenue - cost

    precision = (preds & y_test).sum() / preds.sum()
    recall = (preds & y_test).sum() / y_test.sum()

    pr.append(precision)
    rec.append(recall)

mean_pr = np.round(np.mean(pr), 3)
std_pr = np.round(np.std(pr), 3)

mean_rec = np.round(np.mean(rec), 3)
std_rec = np.round(np.std(rec), 3)

print(f"Mean precision: {mean_pr}\nStandard deviation: {std_pr}\n\nMean recall: {mean_rec}\nStandard deviation: {std_rec}")
# Out:
# Mean precision: 0.297
# Standard deviation: 0.012
#
# Mean recall: 0.67
# Standard deviation: 0.011

# %% [markdown]
# Можно пронаблюдать, что наша модель склоняется к более высокому recall. Попробуйте оценить качество модели с помощью `PR-AUC` в зоне recall $\geq$ 0.5. Сделайте это следующим образом:
# - выберите только те пороги, на которых достигается необходимый recall,
# - затем интерпретируйте отсеченный в единичном квадрате прямоугольник как новый единичный квадрат,
# - посчитайте площадь под отсеченной кривой

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777, stratify=y)
model = LogisticRegression(max_iter=10000)
model.fit(X_train, y_train)

auc_pr, precision, recall = AUC_PR(y_test, model.predict_proba(X_test)[:,1], return_pr=True)
idx = recall > 0.5
auc_pr_segment = auc(recall[idx], precision[idx]) / 0.25

fig, ax = plt.subplots(1, figsize=(6, 6))

ax.plot(recall[idx], precision[idx], color='darkgreen', lw=1.5, label='$Recall > 0.5$')
ax.plot(recall[~idx], precision[~idx], color='darkred', lw=1.5, label='$Recall \leq 0.5$')
ax.set(xlabel='Recall', ylabel='Precision')

ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# __Бонус (0.01 балла):__ что вы кушали в день сдачи данного ДЗ на завтрак?
#
# __Ответ:__ Круассан из буше
